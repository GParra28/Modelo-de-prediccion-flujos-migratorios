# %% [markdown]
# #**TRABAJO FINAL DE MASTER - UPF BSM**
#
# Elaborado por:
#
#
# *   Carlos Santiago Martinez
# *   Gustavo Parra
# * Homero Szturm

# %% [markdown]
# ## **Resumen Ejecutivo**
#
# El presente trabajo tiene como finalidad desarrollar un modelo de aprendizaje automático orientado a la predicción de flujos migratorios internacionales. En un contexto global marcado por la creciente movilidad de personas, entender y anticipar los patrones migratorios se vuelve fundamental para la formulación de políticas públicas efectivas, la planificación territorial y la cooperación internacional.
# El enfoque del proyecto combina conocimientos en ciencia de datos, aprendizaje automático y análisis social. Se partió de la integración de múltiples fuentes de datos internacionales que contienen información sobre movimientos migratorios y condiciones socioeconómicas de distintos países. A partir de esta información, se construyó una base de datos estructurada, estandarizada y enriquecida con indicadores clave, diferenciando entre países de origen y países de destino.
# El proceso implicó tareas complejas de limpieza, transformación e imputación de datos, con el objetivo de obtener una base robusta que permitiera entrenar modelos predictivos. Se trabajó con variables que reflejan tanto las condiciones estructurales de los países como el volumen y tipo de migración observada, generando una estructura que permite modelar relaciones complejas y dinámicas.
# Desde el punto de vista metodológico, se implementó un pipeline de procesamiento de datos y entrenamiento de modelos, asegurando la correcta validación temporal y la aplicabilidad práctica de los resultados. Se prestó especial atención al tratamiento de variables categóricas y a la preservación de la secuencia cronológica en los datos.
# Este proyecto propone una herramienta analítica que, si bien basada en datos históricos, busca ofrecer una mirada prospectiva para la toma de decisiones informadas. En un entorno internacional cada vez más dinámico, el uso de modelos basados en datos y tecnología se vuelve una estrategia clave para anticipar desafíos y diseñar respuestas efectivas en materia de migración.
#
#
# ## **Objetivos**
#
# Objetivo General:
#
# El objetivo principal de este proyecto es el de implementar un modelo de aprendizaje automático capaz de predecir el flujo migratorio entre países. Con este modelo, lo que se busca es contribuir a la planificación y gestión de las políticas migratorias, ayudando así en la cooperación entre naciones y en la implementación de acuerdos en función a las proyecciones futuras.
#
# Objetivos específicos:
#
# *   Crear una base de datos con las características necesarias para poder generar resultados realistas y con utilidad para la toma de decisiones.
# *   Identificar los principales indicadores socioeconómicos que influyen en los movimientos migratorios.
# * Determinar el modelo de aprendizaje automático que mejor se adapte a los datos disponibles
# * Evaluar el rendimiento del modelo mediante métricas adecuadas de validación.
# * Poder generar inputs de calidad para poder utilizarlos a la hora de la toma de decisiones en este campo particular

# %% [markdown]
# #**0. Preparacion de entorno**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/TFM/Data
# Out:
# /content/drive/MyDrive/Colab_Notebooks/TFM/Data

# %%
import pandas as pd
df = pd.read_excel("TFM_Database.xlsx")

# %% [markdown]
# #**1. Analisis Exploratorio**

# %%
#df = df.copy()
#df.drop(['ref_año'], axis=1, inplace=True)

# %% [markdown]
# ## **1.1. Valores Nulos**

# %%
#Vemos los tipos de datos y si hay valores nulos
print(f'{df.info()} \n')
print(f"total null values per column \n", df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77562 entries, 0 to 77561
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ref_año                   77562 non-null  object
#  1   pais_origen               77562 non-null  object
#  2   adquiere_nacionalidad     59667 non-null  float64
#  3   busqueda_asilo            62548 non-null  float64
#  4   migrantes_convencionales  58444 non-null  float64
#  5   salida_de_migrantes       41172 non-null  float64
#  6   migrantes_en_el_pais      53317 non-null  float64
#  7   pais_destino              77562 non-null  object
#  8   año                       77562 non-null  int64
#  9   crecimiento_GDP           77562 non-null  float64
#  10  crecimiento_GDP_2         72436 non-null  float64
#  11  inflación                 77562 non-null  float64
#  12  inflación_2               67928 non-null  float64
#  13  indice_gini               67913 non-null  float64
#  14  indice_gini_2             30194 non-null  float64
#  15  hdi                       77562 non-null  float64
#  16  hdi_2                     71186 non-null  float64
#  17  desempleo                 77562 non-null  float64
#  18  desempleo_2               67729 non-null  float64
#  19  expectativa_de_vida       77562 non-null  float64
#  20  expectativa_de_vida_2     74020 non-null  float64
# dtypes: float64(17), int64(1), object(3)
# memory usage: 12.4+ MB
# None
#
# total null values per column
#  ref_año                         0
# pais_origen                     0
# adquiere_nacionalidad       17895
# busqueda_asilo              15014
# migrantes_convencionales    19118
# salida_de_migrantes         36390
# migrantes_en_el_pais        24245
# pais_destino                    0
# año                             0
# crecimiento_GDP                 0
# crecimiento_GDP_2            5126
# inflación                       0
# inflación_2                  9634
# indice_gini                  9649
# indice_gini_2               47368
# hdi                             0
# hdi_2                        6376
# desempleo                       0
# desempleo_2                  9833
# expectativa_de_vida             0
# expectativa_de_vida_2        3542
# dtype: int64

# %% [markdown]
# Podemos ver que existen una gran variedad de lineas con valores vacios en varios campos, en particular con la data migratoria. Hay que explorar cuales pueden ser algunas razones por la que esto pasa
#
# En el caso de los indicadores economicos, hay casos como del indice GINI el cual sabemos que puede ser complicado de conseguir por pais y no se realiza todos los anios. Lo mismo puede pasar con el HDI (Indice de desarrollo humano). En ese caso el tratamiento sera distinto

# %% [markdown]
# ### **1.1.1 Tratamiento de valores nulos (variables de migrates)**

# %% [markdown]
# Para poder trabajar con cantidades y sin nulos vamos a basar mucho de los analisis en el total general. Pero la informacion de las otras columnas nos va a permitir entender mas en detalle que tipo de migraciones son las que se estan efectuando realmente.
# El hecho de que tengan valores nulos es lago logico, ya que, no necesariamnete hay flujos de todos los tipos de inmigrantes en cada pais cada año

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Seleccionamos las columnas de variables migratorias
migratory_cols = ['busqueda_asilo', 'migrantes_convencionales', 'salida_de_migrantes',
                  'migrantes_en_el_pais', 'adquiere_nacionalidad']

# Crear boxplots para cada variable migratoria
plt.figure(figsize=(15, 10))
for i, col in enumerate(migratory_cols):
    plt.subplot(3, 3, i + 1)  # 3x3 grid
    sns.boxplot(y=df[col])
    plt.title(f'Boxplot of {col}')
    plt.ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# En todas las variables analizadas, la mayoría de los valores se concentran en rangos bajos, mientras que unos pocos casos extremos elevan significativamente los máximos observados.
#
# Esto sugiere una marcada desigualdad entre países en cuanto a población migrante, solicitudes de asilo, adquisición de nacionalidad, entre otros indicadores.
#
# En este caso particular, consideramos que los datos reflejan fielmente la realidad. Por lo tanto, no se aplicarán transformaciones ni filtrados sobre los valores atípicos, ya que representan fenómenos relevantes que deben conservarse en el análisis.

# %% [markdown]
# ### **1.1.2. Decision final sobre migrantes**
# El hecho de tener un dataset con detalles de los migrantes y con altos valores de dispercion nos llevo a tomar 2 decisiones fundamentales.
# 1. Vamos trabajar solo sobre aquellas columnas que implican flujos reales de migrantes, siendo esta la salida de migrantes y entrada de los mismo. Asumiendo que necesariamente tiene que haber un migrante para salir por ende en caso de que la salida sea mayor que la entrada este total tiene que ser 0. Ya que no necesariamente debe existir una registro de una persona ya dentro del pais de destino.
# 2. Vamos a tomar este valor generado por la suma de busqueda_asilo y migrantes_convencionales y le restaremos aquellos que salen del pais, este va a ser el total general

# %%
# Crear la columna con valores válidos, tratando los NaN como ceros
df['total_general'] = (
    df['busqueda_asilo'].fillna(0) +
    df['migrantes_convencionales'].fillna(0) -
    df['salida_de_migrantes'].fillna(0)
)

# Reordenar columnas para poner 'total_general' al principio
cols = ['total_general'] + [col for col in df.columns if col != 'total_general']
df = df[cols]

# %%
#Vemos los tipos de datos y si hay valores nulos
print(f'{df.info()} \n')
print(f"total null values per column \n", df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77562 entries, 0 to 77561
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   total_general             77562 non-null  float64
#  1   ref_año                   77562 non-null  object
#  2   pais_origen               77562 non-null  object
#  3   adquiere_nacionalidad     59667 non-null  float64
#  4   busqueda_asilo            62548 non-null  float64
#  5   migrantes_convencionales  58444 non-null  float64
#  6   salida_de_migrantes       41172 non-null  float64
#  7   migrantes_en_el_pais      53317 non-null  float64
#  8   pais_destino              77562 non-null  object
#  9   año                       77562 non-null  int64
#  10  crecimiento_GDP           77562 non-null  float64
#  11  crecimiento_GDP_2         72436 non-null  float64
#  12  inflación                 77562 non-null  float64
#  13  inflación_2               67928 non-null  float64
#  14  indice_gini               67913 non-null  float64
#  15  indice_gini_2             30194 non-null  float64
#  16  hdi                       77562 non-null  float64
#  17  hdi_2                     71186 non-null  float64
#  18  desempleo                 77562 non-null  float64
#  19  desempleo_2               67729 non-null  float64
#  20  expectativa_de_vida       77562 non-null  float64
#  21  expectativa_de_vida_2     74020 non-null  float64
# dtypes: float64(18), int64(1), object(3)
# memory usage: 13.0+ MB
# None
#
# total null values per column
#  total_general                   0
# ref_año                         0
# pais_origen                     0
# adquiere_nacionalidad       17895
# busqueda_asilo              15014
# migrantes_convencionales    19118
# salida_de_migrantes         36390
# migrantes_en_el_pais        24245
# pais_destino                    0
# año                             0
# crecimiento_GDP                 0
# crecimiento_GDP_2            5126
# inflación                       0
# inflación_2                  9634
# indice_gini                  9649
# indice_gini_2               47368
# hdi                             0
# hdi_2                        6376
# desempleo                       0
# desempleo_2                  9833
# expectativa_de_vida             0
# expectativa_de_vida_2        3542
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calcular el promedio de 'Total general' por país de origen
df_grouped = df.groupby('pais_origen')['total_general'].mean().sort_values(ascending=False).head(10)  # top 10

# Crear gráfico de barras
plt.figure(figsize=(12, 6))
sns.barplot(x=df_grouped.values, y=df_grouped.index, color='firebrick')

plt.title("Promedio de 'Total general' por País de Origen (Top 10)")
plt.xlabel("Total general (promedio)")
plt.ylabel("País de origen")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Agrupar y sumar los valores de "Total general" por país de origen
df_total = df.groupby('pais_destino')['total_general'].sum().sort_values(ascending=False).head(10)  # top 10 países

# Crear el gráfico de barras
plt.figure(figsize=(12, 6))
sns.barplot(x=df_total.values, y=df_total.index, color='firebrick')

plt.title("Cantidad total de migrantes por País de Origen (Top 10)")
plt.xlabel("Total general (suma)")
plt.ylabel("País de origen")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **1.1.2 Tratamiento de valores nulos (variables macroeconomicas)**

# %% [markdown]
# El analisis exploratorio, transformacion y preprocesamiento de los datos se realizo en el anexo titulado **"Analisis exploratorio y preprocesamiento de variables macroeconomicas**.
#
# A continuacion mostraremos a grandes razgos el proceso que realizamos para el tratamiento de valores nulos, outliers y transformaciones de estas variables

# %% [markdown]
# #### **1.1.2.1 Creacion de subset de varianles macroeconomicas**

# %%
# Creamos un subset con datos identificativos como los paises, año y id de columna y las variables macroeconomicas
df_indicators = pd.concat([df[['ref_año','pais_origen', 'pais_destino','año']], df.iloc[:, 10:]], axis=1) # Las columnas 10 en adelante contienen los indicadores macro

# %%
# Mostramos en pantalla las primeras filas para asegurarnos que se creo correctamente el subset
df_indicators.head()
# Out:
#           ref_año           pais_origen   pais_destino   año  crecimiento_GDP  \
# 0  DEU2015SYR2015  Syrian Arab Republic        Germany  2015         2.169499
# 1  DEU2016SYR2016  Syrian Arab Republic        Germany  2016         1.652720
# 2  COL2019VEN2019             Venezuela       Colombia  2019         2.564324
# 3  COL2018VEN2018             Venezuela       Colombia  2018         1.359361
# 4  USA2016MEX2016                Mexico  United States  2016         2.945550
#
#    crecimiento_GDP_2  inflación  inflación_2  indice_gini  indice_gini_2  \
# 0         -10.310340   0.906794    10.927114         30.8            NaN
# 1          -4.179792   0.514426    38.461143         31.7            NaN
# 2                NaN   3.240569          NaN         50.4            NaN
# 3                NaN   4.314313          NaN         49.7            NaN
# 4           2.702323   0.118627     2.720641         41.2            NaN
#
#      hdi  hdi_2  desempleo  desempleo_2  expectativa_de_vida  \
# 0  0.942  0.544      4.981        8.581            81.090244
# 1  0.941  0.552      4.624        8.531            80.641463
# 2  0.766  0.738      9.111        7.217            76.579000
# 3  0.765  0.750      8.872        7.302            76.418000
# 4  0.924  0.769      5.280        4.313            78.690244
#
#    expectativa_de_vida_2
# 0                 65.492
# 1                 63.265
# 2                 72.641
# 3                 71.903
# 4                 74.431

# %% [markdown]
# #### **1.1.2.3. Eliminacion de paises sin data macroeconomica**

# %% [markdown]
# El primer paso que consideramos correcto para limpiar la base de datos de manera eficiente, es eliminar los paises que no tengan data disponible, ya que no tienen mucha utilidad para nuestro modelo
#
# En este caso podemos ver que los problemas vienen principalmente de los paises de origen (indicadores con el numero '2')

# %%
#creamos una lista de los paises sin datos, para posteriormente eliminarlos del df

no_data_countries = [] #lista vacia donde estaran dichos paises

#agrupamos la data por paises y tomamos GDP, un indicador anual.
grouped_countries = df_indicators.groupby('pais_origen')['crecimiento_GDP_2'] # consideramos que si todos son nulos, el resto de indicadores tambien

# creamos un loop que compare el total de valores nulos de 'GDP' con el total de filas
for country, series in grouped_countries:
    # Si el numero coincide entra a la lista y concluimos que no hay data asociada a dicho pais
    if series.isna().sum() == len(series):
        no_data_countries.append(country)

# %%
#Mostramos en pantalla la lista de paises sin data para poder analizarlos
print(f'paises sin data disponible: \n')

for c in no_data_countries:
  print(c)
# Out:
# paises sin data disponible:
#
# Anguilla
# British Virgin Islands
# Caribbean
# Chinese Taipei
# Cook Islands
# Democratic Peopleâ€™s Republic of Korea
# EEA
# European Union (15 countries)
# Falkland Islands (Malvinas)
# Former Czechoslovakia
# Former Netherlands Antilles
# Former Serbia and Montenegro
# Former USSR
# Former Yugoslavia
# French Guiana
# Gibraltar
# Guadeloupe
# Holy See
# Kosovo
# Martinique
# Mayotte
# Montserrat
# New Caledonia
# Niue
# Norfolk Island
# Pitcairn
# RÃ©union
# Saint Helena
# Saint Pierre and Miquelon
# Svalbard and Jan Mayen
# Tokelau
# Wallis and Futuna

# %% [markdown]
# Estos son los paises que tenemos que eliminar de la lista ya que no tienen data macroeconomica asociada a ellos en las bases de datos de la OECD, ONU ni World Bank. Esto puede ser por diferentes razones:
#
#
# *   Pais no reconocido internacionalmente (no tiene codigo pais que coincida con las bases de datos)
# *   No es un pais: Se puede ver en los caasos como World, European Union, Caribbean, etc...
# * Paises con poca trasnparencia o acceso de datos (i.e.: Korea del norte)
#
# En muchos de estos casos, no hay poblaciones muy grandes y por ende, son paises con poco flujos migratorios, por lo que no creemos que afecten gravemente el modelo

# %%
# Eliminamos los registos sin data macroeconomica
df_indicators = df_indicators[~df_indicators['pais_origen'].isin(no_data_countries)]

# %%
# Mostramos en pantalla la metadata del df para ver el impacto
df_indicators.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73511 entries, 0 to 77561
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ref_año                73511 non-null  object
#  1   pais_origen            73511 non-null  object
#  2   pais_destino           73511 non-null  object
#  3   año                    73511 non-null  int64
#  4   crecimiento_GDP        73511 non-null  float64
#  5   crecimiento_GDP_2      72436 non-null  float64
#  6   inflación              73511 non-null  float64
#  7   inflación_2            67796 non-null  float64
#  8   indice_gini            64350 non-null  float64
#  9   indice_gini_2          30194 non-null  float64
#  10  hdi                    73511 non-null  float64
#  11  hdi_2                  71186 non-null  float64
#  12  desempleo              73511 non-null  float64
#  13  desempleo_2            67236 non-null  float64
#  14  expectativa_de_vida    73511 non-null  float64
#  15  expectativa_de_vida_2  73511 non-null  float64
# dtypes: float64(12), int64(1), object(3)
# memory usage: 9.5+ MB

# %% [markdown]
# Al eliminar estos registros quedan 73,511 filas, lo que consideramos que es una cantidad apropiada para el modelo

# %% [markdown]
# #### **1.1.2.4 Datos nulos por crecimeinto de GDP**

# %% [markdown]
# Analizamos solo el GDP de paises de origen, ya que para los paises destino no hay datos nulos

# %%
# Calculamos la cantitdad de valores nulos por Indice GINI de pais orign
gdp_nulls = df_indicators['crecimiento_GDP_2'].isna().sum()

# mostramos en pantalla el porcentaje de valores nulos con respecto al todo el df
print(f"""
Cantidad de valores nulo para gdp de pais origen: {gdp_nulls}
Porcentaje de nulos sobre el total de registros: {round(gdp_nulls/len(df_indicators),3)*100} %
""")
# Out:
# Cantidad de valores nulo para gdp de pais origen: 1075
# Porcentaje de nulos sobre el total de registros: 1.5 %

# %% [markdown]
# #### **1.1.2.5. Datos nulos por inflacion**

# %% [markdown]
# Viendo la cantidad de valores nulos de inflacion vs los de cecimeinto de PIB, tenemos la hipotesis de que para varios paises no se encontraron datos de inflacion. Para comprobar esto Haremos un loop que nos ayude a identificar si esto ocurre

# %%
countries_all_nulls = []

# Group by country
grouped = df_indicators.groupby('pais_origen')

for country, group in grouped:
    total_rows = len(group)
    nulls = group['inflación_2'].isna().sum()

    if nulls == total_rows and total_rows > 0:
        countries_all_nulls.append(country)

print(f"paises sin data de inflacion:\n")
for c in countries_all_nulls:
  print(c)
# Out:
# paises sin data de inflacion:
#
# American Samoa
# Andorra
# Argentina
# Bermuda
# Cuba
# Eritrea
# Faroe Islands
# French Polynesia
# Greenland
# Guam
# Liechtenstein
# Marshall Islands
# Monaco
# Northern Mariana Islands
# Puerto Rico
# Somalia
# Turkmenistan
# Turks and Caicos Islands
# United States Virgin Islands

# %%
# Calculamos la cantitdad de valores nulos por Indice inflacion de pais orign
inf_nulls = df_indicators['inflación_2'].isna().sum()

# mostramos en pantalla el porcentaje de valores nulos con respecto al todo el df
print(f"""
Cantidad de valores nulo para inflacion de pais origen: {inf_nulls}
Porcentaje de nulos sobre el total de registros: {round(inf_nulls/len(df_indicators),2)*100} %
""")
# Out:
# Cantidad de valores nulo para inflacion de pais origen: 5715
# Porcentaje de nulos sobre el total de registros: 8.0 %

# %% [markdown]
# Dado que hay mucha data faltante de ambos indicadores (para paises origen), y de paises clave como Argentina, se decidio buscar data complementaria de el Fondo Monetario Internacional (IMF) para completar los nulos.
#
# Esta manera nos aseguramos que toda la data disponible esta reflejada. Hay paises que posiblemente no tengan data macroeconomica por diferentes razones.

# %% [markdown]
# #### **1.1.2.6. Merge con tabla complementaria de data macroeconomica**

# %%
# %cd /content/drive/MyDrive/TFM/Data/supplemental_data
# Out:
# /content/drive/MyDrive/Colab_Notebooks/TFM/Data/supplemental_data

# %%
import pandas as pd
df_external = pd.read_excel("IMF__supplemental_data_2.xls") # Dataset propietario que contiene data de inflacion, crecimiento de GDP y desempleo (data de IMF)

# %%
#vemos las primeras 5 filas
df_external.head()
# Out:
#   Indicator code Contry code  pais_origen   año inflación_2 crecimiento_GDP_2  \
# 0        AFG1980         AFG  Afghanistan  1980     no data           no data
# 1        AFG1981         AFG  Afghanistan  1981     no data           no data
# 2        AFG1982         AFG  Afghanistan  1982     no data           no data
# 3        AFG1983         AFG  Afghanistan  1983     no data           no data
# 4        AFG1984         AFG  Afghanistan  1984     no data           no data
#
#   desempleo_2
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
import numpy as np

# Remplazamos todas las instancias de 'no data' por NaN
df_external.replace('no data', np.nan, inplace=True)
# Out:
# /tmp/ipython-input-25-4249432755.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_external.replace('no data', np.nan, inplace=True)

# %%
#Hacemos una copia donde le agregamos 1 año a los indicadores de esta data set externo
#Esto es para ser consistentes con el df original y usar datos del año anterior como indicadores (lagging indicator)
df_external_2 = df_external.copy()
df_external_2['año'] = df_external_2['año'] + 1

# %%
# Actualizamos el id de pais + año para que coincida con el df otiginal
df_external_2['Indicator code'] = df_external_2['Contry code'].astype(str) + df_external_2['año'].astype(str)

# %%
df_external_2.head()
# Out:
#   Indicator code Contry code  pais_origen   año  inflación_2  \
# 0        AFG1981         AFG  Afghanistan  1981          NaN
# 1        AFG1982         AFG  Afghanistan  1982          NaN
# 2        AFG1983         AFG  Afghanistan  1983          NaN
# 3        AFG1984         AFG  Afghanistan  1984          NaN
# 4        AFG1985         AFG  Afghanistan  1985          NaN
#
#    crecimiento_GDP_2  desempleo_2
# 0                NaN          NaN
# 1                NaN          NaN
# 2                NaN          NaN
# 3                NaN          NaN
# 4                NaN          NaN

# %%
#creamos un id para los paises origen en el df original para poder hacer el join con la base de datos complementaria
df_indicators['Indicator code'] = df_indicators['ref_año'].astype(str).str[-7:] #los ultimos 7 caracteres corresponden al pais origen y año, el mismo formato del df complementario
# Out:
# /tmp/ipython-input-29-665766503.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_indicators['Indicator code'] = df_indicators['ref_año'].astype(str).str[-7:] #los ultimos 7 caracteres corresponden al pais origen y año, el mismo formato del df complementario

# %%
# Creamos un nuevo data set haciendo un merge del df original y el da la data complementaria del IMF
df_merged = df_indicators.merge(
    df_external_2,
    on='Indicator code',
    how='left',
    suffixes=('', '_ext')
)

# %%
#identificamos las columnas que queremos rellenar
cols_to_fill = ['inflación_2', 'crecimiento_GDP_2', 'desempleo_2']

#Hacemos un loop para rellenar los NaNs de ambas columnas con la data complementaria
for col in cols_to_fill:
    df_merged[col] = df_merged[col].fillna(df_merged[f"{col}_ext"])

# %%
df_merged.head(10)
# Out:
#           ref_año           pais_origen   pais_destino   año  crecimiento_GDP  \
# 0  DEU2015SYR2015  Syrian Arab Republic        Germany  2015         2.169499
# 1  DEU2016SYR2016  Syrian Arab Republic        Germany  2016         1.652720
# 2  COL2019VEN2019             Venezuela       Colombia  2019         2.564324
# 3  COL2018VEN2018             Venezuela       Colombia  2018         1.359361
# 4  USA2016MEX2016                Mexico  United States  2016         2.945550
# 5  USA2017MEX2017                Mexico  United States  2017         1.819451
# 6  DEU2016AFG2016           Afghanistan        Germany  2016         1.652720
# 7  USA2018MEX2018                Mexico  United States  2018         2.457622
# 8  USA2019MEX2019                Mexico  United States  2019         2.966505
# 9  USA2015MEX2015                Mexico  United States  2015         2.523820
#
#    crecimiento_GDP_2  inflación    inflación_2  indice_gini  indice_gini_2  \
# 0         -10.310340   0.906794      10.927114         30.8            NaN
# 1          -4.179792   0.514426      38.461143         31.7            NaN
# 2         -19.700000   3.240569  130060.200000         50.4            NaN
# 3         -15.700000   4.314313     862.600000         49.7            NaN
# 4           2.702323   0.118627       2.720641         41.2            NaN
# 5           1.772493   1.261583       2.821708         41.1           46.9
# 6           1.451315   0.514426      -0.661709         31.7            NaN
# 7           1.871729   2.130110       6.041457         41.2            NaN
# 8           1.972082   2.442583       4.899350         41.4           46.0
# 9           2.503764   1.622223       4.018616         41.5           48.9
#
#    ...  desempleo_2  expectativa_de_vida  expectativa_de_vida_2  \
# 0  ...        8.581            81.090244                 65.492
# 1  ...        8.531            80.641463                 63.265
# 2  ...        7.217            76.579000                 72.641
# 3  ...        7.302            76.418000                 71.903
# 4  ...        4.313            78.690244                 74.431
# 5  ...        3.859            78.539024                 74.376
# 6  ...       11.387            80.641463                 62.270
# 7  ...        3.420            78.539024                 74.261
# 8  ...        3.283            78.639024                 74.301
# 9  ...        4.809            78.841463                 74.404
#
#    Indicator code  Contry code  pais_origen_ext año_ext inflación_2_ext  \
# 0         SYR2015          SYR            Syria  2015.0             NaN
# 1         SYR2016          SYR            Syria  2016.0             NaN
# 2         VEN2019          VEN        Venezuela  2019.0        130060.2
# 3         VEN2018          VEN        Venezuela  2018.0           862.6
# 4         MEX2016          MEX           Mexico  2016.0             2.1
# 5         MEX2017          MEX           Mexico  2017.0             3.4
# 6         AFG2016          AFG      Afghanistan  2016.0             1.1
# 7         MEX2018          MEX           Mexico  2018.0             6.8
# 8         MEX2019          MEX           Mexico  2019.0             4.8
# 9         MEX2015          MEX           Mexico  2015.0             4.1
#
#   crecimiento_GDP_2_ext  desempleo_2_ext
# 0                   NaN              NaN
# 1                   NaN              NaN
# 2                 -19.7             35.6
# 3                 -15.7             27.9
# 4                   2.7              4.3
# 5                   1.8              3.9
# 6                   1.0              NaN
# 7                   1.9              3.4
# 8                   2.0              3.3
# 9                   2.5              4.8
#
# [10 rows x 23 columns]

# %%
# Finalmente eliminamos las columnas adicionales una vez la data ha sido usada para rellenar los valores nulos disponibles
df_merged = df_merged.drop(columns=['inflación_2_ext', 'crecimiento_GDP_2_ext', 'desempleo_2_ext', 'Indicator code',	'Contry code',	'pais_origen_ext',	'año_ext'])

# %%
# Calculamos la cantitdad de valores nulos por Indice GINI de pais orign
gdp_nulls = df_merged['crecimiento_GDP_2'].isna().sum()

# mostramos en pantalla el porcentaje de valores nulos con respecto al todo el df
print(f"""
Cantidad de valores nulo para GDP de pais origen: {gdp_nulls}
Porcentaje de nulos sobre el total de registros: {round(gdp_nulls/len(df_merged),2)*100} %
""")
# Out:
# Cantidad de valores nulo para GDP de pais origen: 467
# Porcentaje de nulos sobre el total de registros: 1.0 %

# %%
# Calculamos la cantitdad de valores nulos por Indice GINI de pais orign
inf_nulls = df_merged['inflación_2'].isna().sum()

# mostramos en pantalla el porcentaje de valores nulos con respecto al todo el df
print(f"""
Cantidad de valores nulo para inflacion de pais origen: {inf_nulls}
Porcentaje de nulos sobre el total de registros: {round(inf_nulls/len(df_merged),2)*100} %
""")
# Out:
# Cantidad de valores nulo para inflacion de pais origen: 2103
# Porcentaje de nulos sobre el total de registros: 3.0 %

# %% [markdown]
# #### **1.1.2.7 Valores nulos para HDI y GINI**

# %% [markdown]
# Estos indices son particulares. Son considerablemente mas dificiles de medir y estan compuestos por diferentes metricas individuales. Debido al la complicacion, falta de estandarizacion y que no tiene temporalidad consistente, en muchos años no habra una actualizacion.
#
# Considerando esto, nos parecio que tiene sentido hacer forward-fill de los nulos. Esta tecnica mantendra el mismo valor de GINI y HDI hasta el proximo año en el que se actualiza, y ese pasa a ser el nuevo valor

# %%
# Calculamos la cantitdad de valores nulos por Indice GINI de pais origen y destino
gini_nulls = df_merged['indice_gini'].isna().sum()
gini_nulls_2 = df_merged['indice_gini_2'].isna().sum()

# mostramos en pantalla el porcentaje de valores nulos con respecto al todo el df
print(f"""
Cantidad de valores nulo para indice GINI de pais destino sobre el total de valores es de: {round(gini_nulls/len(df_merged),3)*100} % \n
Cantidad de valores nulo para indice GINI de pais origen sobre el total de valores es de: {round(gini_nulls_2/len(df_merged),3)*100} %
""")
# Out:
# Cantidad de valores nulo para indice GINI de pais destino sobre el total de valores es de: 12.5 %
#
# Cantidad de valores nulo para indice GINI de pais origen sobre el total de valores es de: 58.9 %

# %%
# Calculamos la cantitdad de valores nulos por Indice HDI de pais origen, ya que para pais destino no existen nulos
hdi_nulls = df_merged['hdi_2'].isna().sum()

# mostramos en pantalla el porcentaje de valores nulos con respecto al todo el df
print(f"""
Cantidad de valores nulo para HDI de pais origen: {hdi_nulls}
Porcentaje de nulos sobre el total de registros: {round(hdi_nulls/len(df_merged),3)*100} %
""")
# Out:
# Cantidad de valores nulo para HDI de pais origen: 2325
# Porcentaje de nulos sobre el total de registros: 3.2 %

# %%
# Procedemos a rellenar los NaNs con la tecnica de forward-fill

df_merged[['indice_gini', 'hdi']] = (
    df_merged
    .sort_values(by=['pais_destino', 'año']) # Primero ordenamos por pais y año para poder agrupar en orden
    .groupby('pais_destino')[['indice_gini', 'hdi']] # aplicamos el group by para que los datos de un mismo año se modifiquen al mismo valor
    .ffill() # Aplicamos el forward filling para rellenar los NaNs hacia adelante para años sin data
    .sort_index()
)

# %%
df_merged.groupby(['pais_destino', 'año'])['indice_gini'].apply(lambda x: x.isna().sum()).loc[lambda x: x > 0]
# Out:
# pais_destino  año
# Australia     2010    199
# Japan         2010    198
# Korea         2010    199
# Mexico        2010    199
# New Zealand   2010    181
#               2011    186
#               2012    201
#               2013    201
#               2014    201
#               2015    197
#               2016    195
#               2017    182
#               2018    182
#               2019    180
# TÃ¼rkiye      2010    151
#               2011    170
#               2012    197
#               2013    199
#               2014    201
#               2015    201
#               2016    198
#               2017    196
# Name: indice_gini, dtype: int64

# %% [markdown]
# En la mayoria de los casos se redujo considerablemente la cantidad de los nulos, SIn emabrgo, todavia existen, en particular en los casos de New Zeland y Turkiye. La razon de esto es que en los primeros años estan vacio y no funcionara el forward-fill para ese rango
#
# La alternativa es revisar si en las bases de datos economicas existen registros del indice GINI antes del 2010 (inicio de nuestro dataset de migraciones) y manualment mapear estos valores para aplicar nuevamente el forward-fill. Otra opcion, que no creemos que es optima es hacer backward fill para estos años, pero puede ser un poco enganoso.

# %%
# Procedemos a rellenar los NaNs con la tecnica de forward-fill

df_merged[['indice_gini_2', 'hdi_2']] = (
    df_merged
    .sort_values(by=['pais_origen', 'año']) # Primero ordenamos por pais y año para poder agrupar en orden
    .groupby('pais_origen')[['indice_gini_2', 'hdi_2']] # aplicamos el group by para que los datos de un mismo año se modifiquen al mismo valor
    .ffill() # Aplicamos el forward filling para rellenar los NaNs hacia adelante para años sin data
    .sort_index()
)

# %%
indicators_4 = ['indice_gini_2', 'hdi_2'] # Columnas de pais de origen

df_merged.groupby('pais_origen')[indicators_4] \
    .apply(lambda x: x.isna().sum()) \
    .loc[lambda df: df.sum(axis=1) > 0] \
    .sort_values(by=indicators_4, ascending=False).head(30)
# Out:
#                                   indice_gini_2  hdi_2
# pais_origen
# Cuba                                        386      0
# Venezuela                                   385      0
# Azerbaijan                                  380      0
# Somalia                                     379    379
# Eritrea                                     379      0
# Uzbekistan                                  379      0
# New Zealand                                 371      0
# Central African Republic                    370      0
# Kuwait                                      369      0
# Trinidad and Tobago                         369      0
# Dominica                                    368      0
# Guyana                                      368      0
# Libya                                       368      0
# Afghanistan                                 367      0
# Belize                                      367      0
# Suriname                                    367      0
# Cambodia                                    365      0
# Saudi Arabia                                365      0
# Turkmenistan                                365      0
# Saint Vincent and the Grenadines            364      0
# Bahamas                                     361      0
# Bahrain                                     361      0
# Barbados                                    361      0
# Singapore                                   361      0
# Oman                                        357      0
# Andorra                                     356      0
# Kiribati                                    356      0
# Saint Kitts and Nevis                       356      0
# Brunei Darussalam                           355      0
# Equatorial Guinea                           355      0

# %% [markdown]
# Procedemos a hacer mapeo manual de datos para ambos indicadores. Estos son datos de fuentes complementarias como la OECD o la ONU, antes de proceder a hacer otro forward filling de ser necesario

# %%
# Mapping dictionary with GINI index values
gini_mapping = {
    ('Australia', 2010): 35.4,
    ('TÃ¼rkiye', 2010): 39, ('TÃ¼rkiye', 2012): 40.3, ('TÃ¼rkiye', 2013): 39.9,
    ('TÃ¼rkiye', 2014): 39, ('TÃ¼rkiye', 2015): 39.8, ('TÃ¼rkiye', 2016): 40.4,
    ('TÃ¼rkiye', 2018): 40.9, ('TÃ¼rkiye', 2019): 39.7, ('TÃ¼rkiye', 2020): 41.5,
    ('Japan', 2010): 34.8, ('Korea', 2010): 32.3, ('Mexico', 2010): 50.8,
    ('New Zealand', 2010): 33, ('New Zealand', 2011): 33.5, ('New Zealand', 2012): 32.9,
    ('New Zealand', 2013): 33.5, ('New Zealand', 2014): 34.1, ('New Zealand', 2015): 34.1,
    ('New Zealand', 2016): 32.5, ('New Zealand', 2017): 33.3, ('New Zealand', 2018): 33.5,
    ('New Zealand', 2019): 33, ('New Zealand', 2020): 32.6, ('New Zealand', 2021): 31.8,
    ('New Zealand', 2022): 30.3, ('New Zealand', 2023): 32.6
}

# Apply mapping using tuple keys
df_merged['indice_gini'] = df_merged.apply(lambda row: gini_mapping.get((row['pais_destino'], row['año']), row['indice_gini']), axis=1)

# %%
# Mapping dictionary with GINI index values
""" En este caso Venezuela utiliza el ultimo valor obtenido (2006) mientras que los otros paises, a excepcion de Nueva Zelanda,
    Toman el valor promedio del periodo 2010 a 2020 segun data de HDR25"""

gini_mapping = {
    ('Venezuela', 2010): 44.7,
    ('Uzbekistan', 2010): 31.2,
    ('Central African Republic', 2010): 43,
    ('Suriname', 2010): 39.2,
    ('Kiribati', 2010): 27.8,
    ('New Zealand', 2010): 33,
    ('New Zealand', 2011): 33.5,
    ('New Zealand', 2012): 32.9,
    ('New Zealand', 2013): 33.5,
    ('New Zealand', 2014): 34.1,
    ('New Zealand', 2015): 34.1,
    ('New Zealand', 2016): 32.5,
    ('New Zealand', 2017): 33.3,
    ('New Zealand', 2018): 33.5,
    ('New Zealand', 2019): 33,
    ('New Zealand', 2020): 32.6,
    ('New Zealand', 2021): 31.8,
    ('New Zealand', 2022): 30.3,
    ('New Zealand', 2023): 32.6,
}

# Apply mapping using tuple keys
df_merged['indice_gini_2'] = df_merged.apply(lambda row: gini_mapping.get((row['pais_origen'], row['año']), row['indice_gini_2']), axis=1)

# %%
# Procedemos a rellenar los NaNs con la tecnica de forward-fill

df_merged[['indice_gini', 'hdi']] = (
    df_merged
    .sort_values(by=['pais_destino', 'año']) # Primero ordenamos por pais y año para poder agrupar en orden
    .groupby('pais_destino')[['indice_gini', 'hdi']] # aplicamos el group by para que los datos de un mismo año se modifiquen al mismo valor
    .ffill() # Aplicamos el forward filling para rellenar los NaNs hacia adelante para años sin data
    .sort_index()
)

# %%
# Procedemos a rellenar los NaNs con la tecnica de forward-fill

df_merged[['indice_gini_2', 'hdi_2']] = (
    df_merged
    .sort_values(by=['pais_origen', 'año']) # Primero ordenamos por pais y año para poder agrupar en orden
    .groupby('pais_origen')[['indice_gini_2', 'hdi_2']] # aplicamos el group by para que los datos de un mismo año se modifiquen al mismo valor
    .ffill() # Aplicamos el forward filling para rellenar los NaNs hacia adelante para años sin data
    .sort_index() # Restauramos el orden original para evitar rellenar los NaNs en un orden equivocado
)

# %%
# Calculamos la cantitdad de valores nulos por Indice GINI de pais orign
gini_nulls = df_merged['indice_gini'].isna().sum()
gini_nulls_2 = df_merged['indice_gini_2'].isna().sum()

# mostramos en pantalla el porcentaje de valores nulos con respecto al todo el df
print(f"""
Cantidad de valores nulo para indice GINI de pais destino sobre el total de valores es de: {round(gini_nulls/len(df_merged),3)*100} % \n
Cantidad de valores nulo para indice GINI de pais origen sobre el total de valores es de: {round(gini_nulls_2/len(df_merged),3)*100} %
""")
# Out:
# Cantidad de valores nulo para indice GINI de pais destino sobre el total de valores es de: 0.0 %
#
# Cantidad de valores nulo para indice GINI de pais origen sobre el total de valores es de: 29.7 %

# %% [markdown]
# Para HDI hay menos incidencias de falta de data, pero nos encontramos que en algunos casos, los paises o territorios no tienen datos para ningun año
#
# Nuevamente vemos casos como Groenlandia, Puerto Rico y Bermuda, que al no ser paises independientes, No tienen registro de HDI en las bases de datos de ONU o el Banco Mundial. Igualmente consideramos que el 3% de oircentaje de nulos es aceptable

# %% [markdown]
# #### **1.1.2.8 Valores nulos para Desempleo**

# %% [markdown]
# En la la tabla de data complementaria estaba incluida la variable de desempelo, por la que ya fue tratada en el paso del merge de las bases de datos macroeconomicas. Posteriormente procedemos a realizar una interposlacion linear. Esta no muestra mucho cambio, por lo que se decidio dejar los nulos como estan

# %%
# Aplicamos una funcion de linear interpolation para los datos de desempleo de pais origen

df_merged['desempleo_2'] = (
    df_merged
    .sort_values(by=['pais_origen', 'año']) # Ordenamos por pais y año para poder agrupar posteriormente
    .groupby('pais_origen')['desempleo_2'] # agrupamos los datos por pais y año para modificar todos los datos de manera conjunta
    .transform(lambda g: g.interpolate(method='linear')) # Utilizamos el metodo lambda para hacer la interpolacion
    .sort_index() # Restauramos el orden original para evitar rellenar los NaNs en un orden equivocado
)

# %% [markdown]
# Finalmente mostraremos en pantalla como quedo el porcentaje de nulos para esta variable de pais destino
#
# Despues de este paso ya hemos tratado todos los nulos, ya que esperanza de vida tiene la data completa

# %%
# Calculamos la cantitdad de valores nulos para desempleo de pais origen
empleo_nulls = df_merged['desempleo_2'].isna().sum()

# mostramos en pantalla el porcentaje de valores nulos con respecto al todo el df
print(f"""
Cantidad de valores nulo para tasa de desemepleo de pais origen: {empleo_nulls}
Porcentaje de nulos sobre el total de registros: {round(empleo_nulls/len(df_merged),3)*100} %
""")
# Out:
# Cantidad de valores nulo para tasa de desemepleo de pais origen: 5227
# Porcentaje de nulos sobre el total de registros: 7.1 %

# %% [markdown]
# ## **1.2. Valores duplicados**

# %%
#para poder extraer las filas duplicadas, usamos la funcion .duplicated
filas_duplicadas = df[df.duplicated()]
print(filas_duplicadas)
# Out:
# Empty DataFrame
# Columns: [total_general, ref_año, pais_origen, adquiere_nacionalidad, busqueda_asilo, migrantes_convencionales, salida_de_migrantes, migrantes_en_el_pais, pais_destino, año, crecimiento_GDP, crecimiento_GDP_2, inflación, inflación_2, indice_gini, indice_gini_2, hdi, hdi_2, desempleo, desempleo_2, expectativa_de_vida, expectativa_de_vida_2]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# En este caso podmeos ver que no hay datos duplicados

# %% [markdown]
# ## **1.3 Estadisticos descriptivos**
#
# Analizamos los estadisticos descriptivos de las variables numericas que tenemos en nuestro dataset antes de proceder a cualquier analisis profundo

# %% [markdown]
# ### **1.3.1 Variables de flujos migratorios**

# %%
df.iloc[:,:9].describe()
# Out:
#        total_general  adquiere_nacionalidad  busqueda_asilo  \
# count   77562.000000           59667.000000    62548.000000
# mean      590.365044             329.150586      145.191261
# std      4943.960234            2291.991989     1903.659145
# min   -124990.000000               0.000000        0.000000
# 25%         0.000000               0.000000        0.000000
# 50%         4.000000               3.000000        0.000000
# 75%        79.000000              45.000000        9.000000
# max    457138.000000          131950.000000   266250.000000
#
#        migrantes_convencionales  salida_de_migrantes  migrantes_en_el_pais
# count              58444.000000         41172.000000          5.331700e+04
# mean                1032.226876           573.666497          1.107311e+04
# std                 6561.696428          4374.127161          1.260018e+05
# min                    0.000000             0.000000          0.000000e+00
# 25%                    1.000000             0.000000          2.000000e+00
# 50%                   23.000000            10.000000          8.200000e+01
# 75%                  240.000000           103.000000          1.384000e+03
# max               309699.000000        198860.000000          8.885060e+06

# %% [markdown]
# Resultados:
#
#
# *   *Inflow of Asylum seekers:* Podemos ver que hay fuerte presencia de outliers viendo los resultados de la data. podemos ver que en el tercer cuartil (3Q) hay 0 ingresos de asilados, pero el valor maximo es 722,364, con una desviacion estandar de 5,376 y media de 298. Esto creemos que puede ser causado por dos factores: 1) hay paises destino que son mas atratctivos que otros (paises de primer mundo como Europa o USA) o estan mas cercanos de paises en crisis; 2) hay anios donde ocurren eventos que crean presion migratoria (i.e: conflicto armado o crisis economicas). Mas adelante haremos mas a analisis para ver considerar si tratamos o no dichos outliers
#
# * *Adquisición de nacionalidad:* Al igual que con la búsqueda de asilo, se observa una fuerte presencia de outliers. El 75% de los valores están por debajo de 45 personas que adquieren nacionalidad, pero el valor máximo es 131,950, con una desviación estándar alta de 2,291. Esto puede estar relacionado con políticas migratorias más abiertas o procesos de regularización masiva en algunos países durante ciertos periodos. También puede reflejar un fenómeno acumulativo en países con comunidades migrantes estables y de largo plazo.
#
# * *Migrantes convencionales:* El comportamiento también es claramente asimétrico. Aunque la mediana es de solo 23 y el 75% está por debajo de 240, el valor máximo alcanza los 309,699. Esto sugiere que pocos países concentran grandes cantidades de migrantes convencionales, posiblemente por factores como oportunidades laborales, estabilidad política o la existencia de redes comunitarias previas. La alta desviación estándar (6,561) refuerza esta idea de concentración y outliers.
#
# * *Salida de migrantes:* Con una media de 573 y una desviación estándar de más de 4,000, se evidencia una gran variabilidad. El 75% de los datos están por debajo de 103, pero el valor máximo es de 198,860. Esto indica que, aunque la mayoría de los países registran salidas bajas, hay casos extremos donde la emigración masiva puede estar asociada a crisis humanitarias, económicas o conflictos armados.
#
# * *Migrantes en el país:* Esta es la variable con mayor dispersión. Aunque la mediana es 29 y el 75% está por debajo de 1,384, el valor máximo llega a más de 8.8 millones. La desviación estándar es extremadamente alta (126,000), lo que evidencia que algunos países reciben o retienen poblaciones migrantes en niveles desproporcionados frente al resto. Esto se puede atribuir a factores como políticas de refugio, tamaño de la población receptora o condiciones económicas favorables.
#
# * *Total general:* Si bien la mediana es de solo 4 personas y el 75% de los datos están por debajo de 79, el valor máximo es de 457,138. La media (620) y la desviación estándar (4,889) también indican fuerte presencia de valores atípicos. Esto confirma que, en general, la mayoría de los movimientos migratorios son pequeños, pero existen eventos excepcionales donde los flujos migratorios son masivos.

# %% [markdown]
# ### **1.3.1 Variables de macroeconomicas**

# %%
#Usamos el atributo .describe() para extraer esta informacion relevante
df_merged.describe()
# Out:
#                 año  crecimiento_GDP  crecimiento_GDP_2     inflación  \
# count  73511.000000     73511.000000       73044.000000  73511.000000
# mean    2014.608644         1.804954           3.013938      1.810087
# std        2.843786         3.342120           5.241226      2.007986
# min     2010.000000       -16.040019         -50.338515     -4.447547
# 25%     2012.000000         0.997833           1.179254      0.507759
# 50%     2015.000000         2.117830           3.168927      1.570255
# 75%     2017.000000         3.164709           5.360344      2.580694
# max     2019.000000        24.615570          86.826748     16.332464
#
#          inflación_2   indice_gini  indice_gini_2           hdi         hdi_2  \
# count   71408.000000  73511.000000   51701.000000  73511.000000  71186.000000
# mean       80.292925     33.171993      37.577886      0.889704      0.706098
# std      3115.557715      5.630418       7.669082      0.046946      0.154593
# min       -29.300000     23.200000      23.200000      0.728000      0.325000
# 25%         1.156562     28.600000      32.300000      0.860000      0.583000
# 50%         2.955644     32.800000      36.000000      0.903000      0.729000
# 75%         6.013609     35.200000      42.600000      0.927000      0.827000
# max    130060.200000     52.600000      63.400000      0.960000      0.960000
#
#           desempleo   desempleo_2  expectativa_de_vida  expectativa_de_vida_2
# count  73511.000000  68284.000000         73511.000000           73511.000000
# mean       8.060650      7.776660            79.872093              71.187870
# std        4.345975      5.815010             2.786499               8.535437
# min        2.243000      0.110000            72.914634              14.665000
# 25%        5.140000      3.776000            78.092683              65.288000
# 50%        7.073000      6.100000            80.948780              72.551000
# 75%        9.432000     10.233000            81.808780              77.571000
# max       27.466000     32.179001            84.210976              86.084000

# %% [markdown]
# *   *GDP Growth:* Esta variable muestra resultados interesantes, por lo general, los paises destino muestran mayor estabilidad en sus crecimeintos de PIB, con desviacion estandar menor y un rango mucho menor que los de los paises de origen, los cuales tienenn indicaciones de presencia de outliers. Tanto los valores maximos como minimos del pais de origen muestran valores mas altos y minimos que los de pais destino. Para un analisis mas concreto calcularemos el delta de los indicadores economicos. Una hipotesis de porque vemos estos valores mas extremos, puede ser la inestabilidad o eventos puntuales. GDP es una medida interanual, por lo que si un pais se recupera rapidamente de una crisis el anio anterior, el crecimiento aislado de ese ano sera elevado aunque no se indicativo de la situacion del pais sin analizar el contexto
#
# * *Inflation*: Lo mismo podemos ver que ocurre en terminos de inflacion. Los paises destino estan caracterizados por bajos niveles de inflacion con una mediana de 1.57% interanual, una desviacion estandar de 2% y Q3 de 2.5%. Hay alguna presencia de outliers (maximo valor de 16%), pero con una media que es solo 3 puntos porcentuales mayor a la mediana, estos no tienen mucho impacto. En el caso de los paises origen la historia es muy diferente con gran variabilidad. La desviacion estandar es de 3k puntos porcentuales y la media y la mediana estan en diferentes ordenes de magnitud. Creemos que este es un factor importante que genera presiones migratorias y esperamos ve paises como Venezuela y Argentina siendo fuertes outliers en este indicador
#
# *   *GINI:* Nos soprendio un poco ya que vemos poca diferencia entre los valores de pais destino. Ambos tienen  medianas cercana (32 y 36, respectivamente), auqnue cabe a destacar que hay mas outliers en los paises de origen que presionan la media a vlaores mas altos. La diferencia real se ve en el tercer cuartil donde podemos ver que para pais de destino el indice GINI es de 35 meintras que para para los paises de origen es 42, lo indica que hay mas desigualdad en los paises de origen. Otro factor a tomar en cuenta es que para pais origen hay un 30% de valores nulos qu correspondend a paises donde por distintos factores (sea de falta de tarnsparecnia, inestabilidad o por ser territorios dependientes) no se mide este indice, pero si nos basamos en otros indicadores, probablemente presionarian la media hacia arriba (un ejemplo claro es Somalia, el cual no tiene data para este indicador). Consideramos que para el modelo es interesante que se mantengan nulos estos valores para el analisis de patrones. La conclusion general es que hay mayores niveles de desigualdad en paises de origen vs los destino.
#
# *   *HDI:* Para este indicador si podemos ver tendencias claras. Los paises destino tienen una mediana de indice de desarrollo humano considerablemente mayor que la de los paises de origen (0.9 vs 0.73). Los paises destino suelen ser de primer mundo evidenciado por alta media y mediana y baja desviacion estandar de tan solo 0.04, lo que indica que la mayoria de los valores estan altamente ranqueados (1 es el valor maximo de esta escala). Para los paises de origen la desviacion estandar es de 0.15, la cual es bastante alta y cabe a destacar que, basandonos en ambos valores maximos, algunos paises destino tambien estan dentro de la lista de pais origen (Nueva Zelanda es un ejemplo que vimos en pasos anteriores), los cuales son outliers positivos. Esa variable creemos que es de alta importancia ya que mide el desarrollo tanto economico como social de los paises y condiciones de vida en general
#
# * *Desempleo:* Esta variable nos llama mucho la atencion ya que es un caso en el cual los resultados son muy similares e incluso mejores para los paises de origen. Creemos que, al igual que con el indice GINI, esto se puede explicar en parte por los valores nulos los cuales corresponden a paises del Caribe, terriotrios dependientes, o paises africanos. De igual manera, se ve que habian altos niveles de desempleo en ambas muestras con medias alrededor de 8% y desviaciones estandar altas (entre 4.3 y 5.8 puntos porcentuales)
#
# * *Expectativa de Vida:* Como era de esperarse, en este indicador hay altas discrepancias entre los valores de paises destino y origen. La mediana de esperanza de vida de los paises destino es de 81 años vs 73 años para los paises de origen. para pais de origen hay poca desviacion en esta metrica con la diferencia entre el Q1 y el Q3 siendo solo 4 años, mientras que en el caso de los paises origen es de mas de 12. cabe a destacar que el valor minmo observado para pais origen es de 14 años, lo que es evidentemente un error, dado a que los valores mas bajos son de ~50 años (corresponde a Chad, Lesotot y Central African Republic, segun Statista). EL valor minimo real es de ~45 años y corresponde a Central African Republic en 2015. Segun nuestra hipotesis, esta es una de las variables mas importantes ya que refleja las condiciones de salud y en gran parte seguridad de los paises, factores clave en la calidad de vida de las personas.

# %% [markdown]
# **Boxplot**

# %% [markdown]
# # **2. Transformacion de variables y feature engineering**

# %% [markdown]
# ## **2.1 Delta de de variables economicas**

# %% [markdown]
# Nos parece que para no tener exceso de features, con valores repetidos, es mejor calcular el diferencial entre los diferentes indices macroecnomicos de los paises involucrados

# %%
# Hacemos una lista con los nombres de las columnas de indicadores, excluyendo las que sean de pais de origen
indicators = [col for col in df_merged.columns[4:] if not col.endswith('_2')]

# hacemos un for loop para calcular el diferencial por indicador de pais origen y destino
for col in indicators:
    origen_col = f"{col}_2" # variables de pais origen
    delta_col = f"Δ_{col}" # variables de pais destino
    df_merged[delta_col] = df_merged[col] - df_merged[origen_col] # creacion de las nuevas columnas mostrando el delta

# %%
#eliminamos las columnas originales y solo dejamos las que continen el diferencial
df_merged = df_merged.drop(columns=['crecimiento_GDP',	'crecimiento_GDP_2',	'inflación',
                        'inflación_2',	'indice_gini', 'indice_gini_2',
                        'hdi',	'hdi_2',	'desempleo',	'desempleo_2',
                        'expectativa_de_vida',	'expectativa_de_vida_2'])

# %%
df_merged.head()
# Out:
#           ref_año           pais_origen   pais_destino   año  \
# 0  DEU2015SYR2015  Syrian Arab Republic        Germany  2015
# 1  DEU2016SYR2016  Syrian Arab Republic        Germany  2016
# 2  COL2019VEN2019             Venezuela       Colombia  2019
# 3  COL2018VEN2018             Venezuela       Colombia  2018
# 4  USA2016MEX2016                Mexico  United States  2016
#
#    Δ_crecimiento_GDP    Δ_inflación  Δ_indice_gini  Δ_hdi  Δ_desempleo  \
# 0          12.479839     -10.020320           -9.6  0.398       -3.600
# 1           5.832511     -37.946717           -8.7  0.389       -3.907
# 2          22.264324 -130056.959431            5.7  0.028        1.894
# 3          17.059361    -858.285687            5.0  0.015        1.570
# 4           0.243227      -2.602014           -7.7  0.155        0.967
#
#    Δ_expectativa_de_vida
# 0              15.598244
# 1              17.376463
# 2               3.938000
# 3               4.515000
# 4               4.259244

# %% [markdown]
# Podemos ver que es mucho mas limpio y reducimos la proabilidad de generar overfitting en el modelo mas adelante

# %% [markdown]
# ## **2.2. Analisis de outliers**

# %% [markdown]
# **Boxplot**

# %%
#Primero haremos analisis de la distirbucion de algunas variables numericas

#importamos las bibliotecas para graficar
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#hacemos uso de subplots para ver los graficos lado a lado
ig, axes = plt.subplots(1, 6, figsize=(20, 6))  # (rows, columns)

#primero hacemos el boxplot de GDP
sns.boxplot(x='Δ_crecimiento_GDP', data=df_merged, ax=axes[0], color='firebrick')
axes[0].set_title("Box plot de Δ_crecimiento_GDP")

#luego procedemos a hacer el grafico para inflación
sns.boxplot(x='Δ_inflación', data=df_merged, ax=axes[1], color='firebrick')
axes[1].set_title("Box plot de Δ_inflación")

#luego procedemos a hacer el grafico para GINI
sns.boxplot(x='Δ_indice_gini', data=df_merged, ax=axes[2], color='firebrick')
axes[2].set_title("Box plot de Δ_indice_gini")

#luego procedemos a hacer el grafico para HDI
sns.boxplot(x='Δ_hdi', data=df_merged, ax=axes[3], color='firebrick')
axes[3].set_title("Box plot de Δ_hdi")

#luego procedemos a hacer el grafico para Desempleo
sns.boxplot(x='Δ_desempleo', data=df_merged, ax=axes[4], color='firebrick')
axes[4].set_title("Box plot de Δ_desempleo")

#luego procedemos a hacer el grafico para expectativa de vida
sns.boxplot(x='Δ_expectativa_de_vida', data=df_merged, ax=axes[5], color='firebrick')
axes[5].set_title("Box plot Δ_expectativa_de_vida")

plt.tight_layout()
plt.show()

# %% [markdown]
# **Histograma**

# %%
# En todos los histogramas usamos el parametro rice para decidir la cantidad de bins

#hacemos uso de subplots para ver los graficos lado a lado
ig, axes = plt.subplots(1, 6, figsize=(20, 6))  # (rows, columns)

#histograma de GDP
sns.histplot(x='Δ_crecimiento_GDP', bins='rice' ,data=df_merged, ax=axes[0], color='firebrick' )
axes[0].set_title("Box plot de Δ_crecimiento_GDP")

#histograma de inflación
sns.histplot(x='Δ_inflación', bins='rice' ,data=df_merged, ax=axes[1], color='firebrick' )
axes[1].set_title("Box plot de Δ_inflación")

#histograma de GINI
sns.histplot(x='Δ_indice_gini', bins='rice' ,data=df_merged, ax=axes[2], color='firebrick' )
axes[2].set_title("Box plot de Δ_indice_gini")

#histograma de HDI
sns.histplot(x='Δ_hdi', bins='rice' ,data=df_merged, ax=axes[3], color='firebrick' )
axes[3].set_title("Box plot de Δ_hdi")

#histograma de Desempleo
sns.histplot(x='Δ_desempleo', bins='rice' ,data=df_merged, ax=axes[4], color='firebrick' )
axes[4].set_title("Box plot de Δ_desempleo")

#histograma de Expectativa de vida
sns.histplot(x='Δ_expectativa_de_vida', bins='rice' ,data=df_merged, ax=axes[5], color='firebrick')
axes[5].set_title("Box plot de Δ_expectativa_de_vida")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **2.4. Dateframe final**

# %%
# Creamos un nuevo data set haciendo un merge del df original y el df merged que contiene los features preprocesados
df_final = df_merged.merge(
    df,
    on='ref_año',
    how='left',
    suffixes=('', '_ext')
)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73511 entries, 0 to 73510
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ref_año                   73511 non-null  object
#  1   pais_origen               73511 non-null  object
#  2   pais_destino              73511 non-null  object
#  3   año                       73511 non-null  int64
#  4   Δ_crecimiento_GDP         73044 non-null  float64
#  5   Δ_inflación               71408 non-null  float64
#  6   Δ_indice_gini             51701 non-null  float64
#  7   Δ_hdi                     71186 non-null  float64
#  8   Δ_desempleo               68284 non-null  float64
#  9   Δ_expectativa_de_vida     73511 non-null  float64
#  10  total_general             73511 non-null  float64
#  11  pais_origen_ext           73511 non-null  object
#  12  adquiere_nacionalidad     57149 non-null  float64
#  13  busqueda_asilo            61414 non-null  float64
#  14  migrantes_convencionales  56063 non-null  float64
#  15  salida_de_migrantes       39394 non-null  float64
#  16  migrantes_en_el_pais      51075 non-null  float64
#  17  pais_destino_ext          73511 non-null  object
#  18  año_ext                   73511 non-null  int64
#  19  crecimiento_GDP           73511 non-null  float64
#  20  crecimiento_GDP_2         72436 non-null  float64
#  21  inflación                 73511 non-null  float64
#  22  inflación_2               67796 non-null  float64
#  23  indice_gini               64350 non-null  float64
#  24  indice_gini_2             30194 non-null  float64
#  25  hdi                       73511 non-null  float64
#  26  hdi_2                     71186 non-null  float64
#  27  desempleo                 73511 non-null  float64
#  28  desempleo_2               67236 non-null  float64
#  29  expectativa_de_vida       73511 non-null  float64
#  30  expectativa_de_vida_2     73511 non-null  float64
# dtypes: float64(24), int64(2), object(5)
# memory usage: 17.4+ MB

# %%
# hacemos drop a las columnas innecesarias de df

# list comprenhension de las columnas que eliminaremos
columns_to_drop = [c for c in df_final.columns[10:] if c != 'total_general'] #las columnas 10 en adelante son todas de df original, donde solo queremos total general

#mostramos en pantalla las columnas a elminiar para chequear que no eliminemos erroneamente
for c in columns_to_drop:
    print(c)
# Out:
# pais_origen_ext
# adquiere_nacionalidad
# busqueda_asilo
# migrantes_convencionales
# salida_de_migrantes
# migrantes_en_el_pais
# pais_destino_ext
# año_ext
# crecimiento_GDP
# crecimiento_GDP_2
# inflación
# inflación_2
# indice_gini
# indice_gini_2
# hdi
# hdi_2
# desempleo
# desempleo_2
# expectativa_de_vida
# expectativa_de_vida_2

# %% [markdown]
# ### **2.5 Cambio de nombre de paises y eliminacion paises poco significantes**

# %%
df_final = df_final.drop(columns=columns_to_drop)

# %%
# Vamos a reemplazar algunos nombres de países de origen para que sean más significativos
replacements = {
    "China (Peopleâ€™s Republic of)": "China",
    "Palestinian Authority or West Bank and Gaza Strip": "Palestine",
    "CÃ´te dâ€™Ivoire": "Côte d'Ivoire",
    "Lao Peopleâ€™s Democratic Republic": "Laos",
    "Former Serbia and Montenegro": "Serbia and Montenegro",
    "Democratic Peopleâ€™s Republic of Korea": "North Korea",
    "TÃ¼rkiye": "Turkey",
    "Turks and Caicos Islands": "Turks and Caicos Islands"
}

# Aplicar reemplazos sobre la columna pais_origen
df_final['pais_origen'] = df_final['pais_origen'].replace(replacements)

# %%
# Eliminar filas con 'EEA' o 'European Union (15 countries)' en la columna 'pais_origen'
df_final = df_final[~df_final['pais_origen'].isin(['EEA', 'European Union (15 countries)'])]

# %%
replacements_destino = {
    "TÃ¼rkiye": "Turkey"
}

df_final['pais_destino'] = df_final['pais_destino'].replace(replacements_destino)

# %%
df_final.head()
# Out:
#           ref_año           pais_origen   pais_destino   año  \
# 0  DEU2015SYR2015  Syrian Arab Republic        Germany  2015
# 1  DEU2016SYR2016  Syrian Arab Republic        Germany  2016
# 2  COL2019VEN2019             Venezuela       Colombia  2019
# 3  COL2018VEN2018             Venezuela       Colombia  2018
# 4  USA2016MEX2016                Mexico  United States  2016
#
#    Δ_crecimiento_GDP    Δ_inflación  Δ_indice_gini  Δ_hdi  Δ_desempleo  \
# 0          12.479839     -10.020320           -9.6  0.398       -3.600
# 1           5.832511     -37.946717           -8.7  0.389       -3.907
# 2          22.264324 -130056.959431            5.7  0.028        1.894
# 3          17.059361    -858.285687            5.0  0.015        1.570
# 4           0.243227      -2.602014           -7.7  0.155        0.967
#
#    Δ_expectativa_de_vida  total_general
# 0              15.598244       457138.0
# 1              17.376463       412073.0
# 2               3.938000       217039.0
# 3               4.515000       204259.0
# 4               4.259244       201422.0

# %% [markdown]
# ## **2.6. Matriz de correlaciones**

# %%
numericas_df = df_final.iloc[:, -7:] # Tomamos la variables numericas unicamente

# 2. Calculate the correlation matrix *of* this DataFrame.
matrix = numericas_df.corr()

plt.figure(figsize=(15, 10))
sns.heatmap(matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Matriz de Correlación de las Últimas 5 Columnas")
plt.show()

# %% [markdown]
# Viendo los resultados de la matriz de correlacion, llegamos a la conclusion de que en general hay poca correlacion entre las variables y con el total general, el cual sera nuestro target.
#
# Sin embargo, hay unas excepciones entendibles. Expectativa de vida tiene alta correlacion con HDI. Esto se debe a que este indicador es un componente importante del HDI y por ende no son independientes. Con el caso GINI pasa algo similar y tiene correlacion negativa moderada con HDI y expecativa de vida por las mismas razones. Tenemos que recordar que un indice GINI menor significa menor desigualdad.
#
# Creeemos que debido de la alta correlacion de estas variables, lo mejor para el modelo es prescindir de HDI, la cual es la que presenta mayores niveles de correlacion con otras variables

# %%
# Hacemos drop de la columna HDI
df_final = df_final.drop(columns='Δ_hdi')

# %%
df_final.head()
# Out:
#           ref_año           pais_origen   pais_destino   año  \
# 0  DEU2015SYR2015  Syrian Arab Republic        Germany  2015
# 1  DEU2016SYR2016  Syrian Arab Republic        Germany  2016
# 2  COL2019VEN2019             Venezuela       Colombia  2019
# 3  COL2018VEN2018             Venezuela       Colombia  2018
# 4  USA2016MEX2016                Mexico  United States  2016
#
#    Δ_crecimiento_GDP    Δ_inflación  Δ_indice_gini  Δ_desempleo  \
# 0          12.479839     -10.020320           -9.6       -3.600
# 1           5.832511     -37.946717           -8.7       -3.907
# 2          22.264324 -130056.959431            5.7        1.894
# 3          17.059361    -858.285687            5.0        1.570
# 4           0.243227      -2.602014           -7.7        0.967
#
#    Δ_expectativa_de_vida  total_general
# 0              15.598244       457138.0
# 1              17.376463       412073.0
# 2               3.938000       217039.0
# 3               4.515000       204259.0
# 4               4.259244       201422.0

# %% [markdown]
# # **3. Modelos de Machine Learning**

# %% [markdown]
# En nuestro proceso, experimentaremos con tres modelos distintos para ir evaluando cual es el mas efectivo y eficiente en tiempo para hacer predicciones sobre el total general
#
# Los siguientes son los modelos que utlizamos:
#
#
# 1.   Linear Regresion
# 2.   Random Forest Regressor
# 3. CatBoost (Un tipo de Gradient Boost Regressor)

# %%
# Librerias necesarias
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error
import sklearn.metrics as sklearn
from sklearn.model_selection import cross_val_score, KFold

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.15.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (8.5.0)
# Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl (99.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.3 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.8

# %% [markdown]
# ## **3.1. Train/ Test split**

# %%
# Primero ordenamos la data por orden chronologico
df_sorted = df_final.sort_values(by='año')

# Definimos el año limite que determinara la muestra de train
cutoff = 2017

# %%
df_sorted = df_sorted.drop(columns='ref_año')

# %% [markdown]
# ## **3.2. Pipeline de preprocessing**

# %% [markdown]
# ### **3.2.1. Pipeline Modelos 1**

# %% [markdown]
# El modelo de Random Forest Regressor no puede tratar los valores nulos (NaN) de manera nativa, por lo que el pipeline tiene que incluir un Imputer para poder tratar estos valores y posteriormente correr el modelo

# %%
# Para los modelos que no aceptan los NAN
#hacemos una separacion de features ya que las numericas y las categoricas tienen tratamiento distinto
numeric_features = list(df_final.columns[4:9]) # Excluimos año, pero mantenmos los indicadores macroeconomicos
categorical_features = ['pais_origen', 'pais_destino'] # Solo los paises son categoricas
# Al final se juntan ambos features cuando llegue el momento de entrenar el modelo y ya esten preprocesadas las features
features = categorical_features + numeric_features
# definimos el target del modelo que es la cantidad de migrantes entre pais de origen y destino
target = 'total_general'

# Preprocesadores
cat_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# ColumnTransformer que aplica transformaciones según tipo de columna
preprocessor_1 = ColumnTransformer([
    ('num', num_pipeline, numeric_features),
    ('cat', cat_pipeline, categorical_features)
])

df_train =  df_sorted[df_sorted['año'] <= cutoff]
df_test = df_sorted[df_sorted['año'] > cutoff]

X_train = df_train[features]
y_train = df_train[target]
X_test = df_test[features]
y_test = df_test[target]

# %%
df_train.head()
# Out:
#       pais_origen pais_destino   año  Δ_crecimiento_GDP  Δ_inflación  \
# 6849      Ukraine       France  2010          12.311916   -15.793572
# 6846        China        Chile  2010         -10.516763     1.081210
# 6843       Greece  Netherlands  2010           0.453986    -0.020296
# 69818     Andorra      Finland  2010          -2.773184    -1.000001
# 6876    Singapore       Canada  2010          -3.043040    -0.297253
#
#        Δ_indice_gini  Δ_desempleo  Δ_expectativa_de_vida  total_general
# 6849             7.4       -0.104              12.255634          821.0
# 6846             NaN        6.593               3.573000          822.0
# 6843            -5.7       -5.269               0.360976          822.0
# 69818            NaN          NaN              -4.380488            0.0
# 6876             NaN        2.484              -0.175366          814.0

# %% [markdown]
# ### **3.2.2 Pipeline Modelo 2**

# %%
from catboost import CatBoostRegressor

# Preprocesadores
numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler()) #aplicamos estandarizacion a las variables numericas
])

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore')) # One hot Encoder para las categoricas ya que no son ordinales
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ], remainder='passthrough') #esto permite mantener el año tal cual como esta

model = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', CatBoostRegressor())
])

# %% [markdown]
# ## **3.3.Random Forest Regressor**

# %%
# Pipeline completo con modelo
model_imputer = Pipeline([
    ('preprocessing', preprocessor_1),
    ('model', RandomForestRegressor())
])

model_imputer.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Δ_crecimiento_GDP',
#                                                    'Δ_inflación',
#                                                    'Δ_indice_gini',
#                                                    'Δ_desempleo',
#                                                    'Δ_expectativa_de_vida']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['pais_origen',
#                                                    'pais_destino'])])),
#                 ('model', RandomForestRegressor())])

# %%
y_pred = model_imputer.predict(X_test)
test_mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error Test: \t{test_mse}")

y_pred_train = model_imputer.predict(X_train)
train_mse = mean_squared_error(y_train, y_pred_train)
print(f"Mean Squared Error Train: \t{train_mse}")
# Out:
# Mean Squared Error Test: 	14370631.850913374
# Mean Squared Error Train: 	1509345.5534484114

# %%
from sklearn.metrics import r2_score
y_test_pred = model_imputer.predict(X_test)

# Compute R^2 on test data
r2_test = r2_score(y_test, y_test_pred)
print(f"Test R^2: {r2_test:.4f}")
# Out:
# Test R^2: 0.5405

# %%
from sklearn.metrics import mean_absolute_error

# Predictions (assuming model has already been fitted)
y_pred_test = model_imputer.predict(X_test)
y_pred_train_2 = model_imputer.predict(X_train)

# Calculate MAE
test_mae = mean_absolute_error(y_test, y_pred_test)
train_mae = mean_absolute_error(y_train, y_pred_train)

print(f"Mean Absolute Error Test: \t{test_mae}")
print(f"Mean Absolute Error Train: \t{train_mae}")
# Out:
# Mean Absolute Error Test: 	496.30669402028525
# Mean Absolute Error Train: 	105.67468776215287

# %% [markdown]
# ## **3.4. CatBoost + RandomSearchCV**

# %% [markdown]
# Despues de hacer unas pruebas con CatBoost, nos dimos cuenta que era considerablemente mas rapido que el Random Forest Regressor y permite mantener los NaNs sin necesidad de aplicar un Imputer, lo que permite mantener data mas fiel a la realidad
#
# Como CatBoost es un modelo iterativo basado en Gradient Boost Regression, Hay varios hyperparametros que se pueden afinar. Para esto aplicamos el RandomSearch con tres hyperparametros con 3 valores cada uno.

# %%
# En este caso necesitamos hacer 3 splits uno de train uno de validacion y otro de test, asi evitamos que el modelo tenga acceso a la data de prueba mientras hace las iteraciones
train_cutoff = 2016
val_cutoff = 2017

df_train = df_sorted[df_sorted['año'] <= train_cutoff]
df_val = df_sorted[(df_sorted['año'] > train_cutoff) & (df_sorted['año'] <= val_cutoff)]
##df_test = df_sorted[df_sorted['año'] > val_cutoff]

X_train = df_train[features]
y_train = df_train[target]
X_val = df_val[features]
y_val = df_val[target]


X_trainval = pd.concat([X_train, X_val])
y_trainval = pd.concat([y_train, y_val])

# %%
from sklearn.model_selection import RandomizedSearchCV, TimeSeriesSplit

param_distributions = {
    'classifier__depth': [4,6],
    'classifier__learning_rate': [0.1, 0.05, 0.03],
    'classifier__iterations': [1000, 2000, 5000]
}

tscv = TimeSeriesSplit(n_splits=3)

random_search = RandomizedSearchCV(
    model,
    param_distributions=param_distributions,
    n_iter=10,
    scoring='neg_mean_squared_error',
    cv=tscv,
    verbose=2,
    n_jobs=-1
)

random_search.fit(X_trainval, y_trainval)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# 0:	learn: 4824.7704283	total: 56.4ms	remaining: 4m 42s
# 1:	learn: 4701.2731806	total: 67.9ms	remaining: 2m 49s
# 2:	learn: 4626.1818710	total: 75.9ms	remaining: 2m 6s
# 3:	learn: 4526.4416264	total: 83.8ms	remaining: 1m 44s
# 4:	learn: 4466.4892275	total: 91.6ms	remaining: 1m 31s
# 5:	learn: 4414.1252885	total: 99.7ms	remaining: 1m 22s
# 6:	learn: 4366.9989544	total: 107ms	remaining: 1m 16s
# 7:	learn: 4276.7216467	total: 115ms	remaining: 1m 12s
# 8:	learn: 4241.1323706	total: 123ms	remaining: 1m 8s
# 9:	learn: 4207.1053055	total: 131ms	remaining: 1m 5s
# 10:	learn: 4142.3684762	total: 139ms	remaining: 1m 3s
# 11:	learn: 4114.1346428	total: 147ms	remaining: 1m 1s
# 12:	learn: 4053.1322944	total: 155ms	remaining: 59.6s
# 13:	learn: 3996.4487987	total: 163ms	remaining: 58.2s
# 14:	learn: 3966.6022948	total: 171ms	remaining: 56.9s
# 15:	learn: 3910.5277906	total: 179ms	remaining: 55.9s
# 16:	learn: 3865.3173593	total: 188ms	remaining: 55s
# 17:	learn: 3842.6297351	total: 196ms	remaining: 54.1s
# 18:	learn: 3794.0460552	total: 206ms	remaining: 53.9s
# 19:	learn: 3748.2363259	total: 214ms	remaining: 53.2s
# 20:	learn: 3724.5014005	total: 222ms	remaining: 52.6s
# 21:	learn: 3681.3959172	total: 230ms	remaining: 52s
# 22:	learn: 3659.0704432	total: 238ms	remaining: 51.4s
# 23:	learn: 3620.5183224	total: 250ms	remaining: 51.9s
# 24:	learn: 3581.5605566	total: 259ms	remaining: 51.5s
# 25:	learn: 3561.6965540	total: 267ms	remaining: 51s
# 26:	learn: 3526.5440723	total: 275ms	remaining: 50.7s
# 27:	learn: 3492.8428069	total: 283ms	remaining: 50.3s
# 28:	learn: 3445.9609698	total: 291ms	remaining: 49.9s
# 29:	learn: 3431.9666633	total: 299ms	remaining: 49.6s
# 30:	learn: 3389.7096189	total: 307ms	remaining: 49.3s
# 31:	learn: 3362.6542980	total: 316ms	remaining: 49s
# 32:	learn: 3331.2731642	total: 324ms	remaining: 48.8s
# 33:	learn: 3305.9047369	total: 333ms	remaining: 48.6s
# 34:	learn: 3274.8427053	total: 341ms	remaining: 48.4s
# 35:	learn: 3255.8703171	total: 350ms	remaining: 48.2s
# 36:	learn: 3240.6485994	total: 358ms	remaining: 48.1s
# 37:	learn: 3216.7770976	total: 367ms	remaining: 47.9s
# 38:	learn: 3196.5126141	total: 375ms	remaining: 47.7s
# 39:	learn: 3183.1400099	total: 384ms	remaining: 47.6s
# 40:	learn: 3169.9645827	total: 392ms	remaining: 47.4s
# 41:	learn: 3154.2663654	total: 401ms	remaining: 47.3s
# 42:	learn: 3143.3444498	total: 408ms	remaining: 47.1s
# 43:	learn: 3121.0010730	total: 419ms	remaining: 47.2s
# 44:	learn: 3109.4959336	total: 427ms	remaining: 47s
# 45:	learn: 3088.9901943	total: 436ms	remaining: 46.9s
# 46:	learn: 3079.0434924	total: 446ms	remaining: 47s
# 47:	learn: 3070.4559300	total: 455ms	remaining: 46.9s
# 48:	learn: 3054.3176340	total: 464ms	remaining: 46.8s
# 49:	learn: 3037.9453537	total: 473ms	remaining: 46.9s
# 50:	learn: 3028.2217793	total: 482ms	remaining: 46.8s
# 51:	learn: 3007.3081402	total: 491ms	remaining: 46.7s
# 52:	learn: 2993.1651029	total: 500ms	remaining: 46.7s
# 53:	learn: 2975.0651405	total: 509ms	remaining: 46.6s
# 54:	learn: 2970.6443740	total: 517ms	remaining: 46.5s
# 55:	learn: 2955.0662839	total: 526ms	remaining: 46.4s
# 56:	learn: 2945.5382851	total: 535ms	remaining: 46.4s
# 57:	learn: 2934.5805784	total: 543ms	remaining: 46.3s
# 58:	learn: 2918.5886053	total: 552ms	remaining: 46.2s
# 59:	learn: 2906.9601759	total: 560ms	remaining: 46.1s
# 60:	learn: 2897.9987299	total: 568ms	remaining: 46s
# 61:	learn: 2894.0324788	total: 577ms	remaining: 46s
# 62:	learn: 2881.8251424	total: 586ms	remaining: 45.9s
# 63:	learn: 2873.8610283	total: 594ms	remaining: 45.8s
# 64:	learn: 2862.9019673	total: 603ms	remaining: 45.7s
# 65:	learn: 2857.3119746	total: 611ms	remaining: 45.7s
# 66:	learn: 2846.9637548	total: 619ms	remaining: 45.6s
# 67:	learn: 2840.7204745	total: 628ms	remaining: 45.5s
# 68:	learn: 2835.8861761	total: 639ms	remaining: 45.7s
# 69:	learn: 2825.6600973	total: 648ms	remaining: 45.6s
# 70:	learn: 2814.6418092	total: 656ms	remaining: 45.6s
# 71:	learn: 2802.1777889	total: 665ms	remaining: 45.5s
# 72:	learn: 2796.2734131	total: 673ms	remaining: 45.4s
# 73:	learn: 2788.5255568	total: 681ms	remaining: 45.4s
# 74:	learn: 2777.6576815	total: 690ms	remaining: 45.3s
# 75:	learn: 2767.8659406	total: 698ms	remaining: 45.2s
# 76:	learn: 2760.1107452	total: 707ms	remaining: 45.2s
# 77:	learn: 2756.2686706	total: 715ms	remaining: 45.1s
# 78:	learn: 2746.3037902	total: 725ms	remaining: 45.1s
# 79:	learn: 2734.9529582	total: 733ms	remaining: 45.1s
# 80:	learn: 2731.1354920	total: 741ms	remaining: 45s
# 81:	learn: 2720.8296864	total: 750ms	remaining: 45s
# 82:	learn: 2714.2033273	total: 761ms	remaining: 45.1s
# 83:	learn: 2706.6899812	total: 769ms	remaining: 45s
# 84:	learn: 2700.0362976	total: 778ms	remaining: 45s
# 85:	learn: 2689.8312746	total: 786ms	remaining: 44.9s
# 86:	learn: 2685.3654864	total: 795ms	remaining: 44.9s
# 87:	learn: 2680.9908418	total: 808ms	remaining: 45.1s
# 88:	learn: 2674.4273394	total: 833ms	remaining: 45.9s
# 89:	learn: 2666.6554119	total: 845ms	remaining: 46.1s
# 90:	learn: 2660.0669879	total: 854ms	remaining: 46s
# 91:	learn: 2656.5816498	total: 863ms	remaining: 46s
# 92:	learn: 2649.7312411	total: 871ms	remaining: 45.9s
# 93:	learn: 2644.3644470	total: 879ms	remaining: 45.9s
# 94:	learn: 2636.6171369	total: 888ms	remaining: 45.8s
# 95:	learn: 2632.9339670	total: 896ms	remaining: 45.8s
# 96:	learn: 2629.7576849	total: 905ms	remaining: 45.7s
# 97:	learn: 2621.4680317	total: 913ms	remaining: 45.7s
# 98:	learn: 2612.4030107	total: 922ms	remaining: 45.6s
# 99:	learn: 2603.5100374	total: 930ms	remaining: 45.6s
# 100:	learn: 2596.6358198	total: 939ms	remaining: 45.5s
# 101:	learn: 2589.1017213	total: 947ms	remaining: 45.5s
# 102:	learn: 2580.6462283	total: 956ms	remaining: 45.4s
# 103:	learn: 2574.0136174	total: 966ms	remaining: 45.5s
# 104:	learn: 2567.8990235	total: 975ms	remaining: 45.5s
# 105:	learn: 2560.5796808	total: 984ms	remaining: 45.4s
# 106:	learn: 2553.4424529	total: 992ms	remaining: 45.3s
# 107:	learn: 2550.6946125	total: 1s	remaining: 45.3s
# 108:	learn: 2545.2970660	total: 1.01s	remaining: 45.3s
# 109:	learn: 2538.7897499	total: 1.02s	remaining: 45.2s
# 110:	learn: 2530.6294076	total: 1.03s	remaining: 45.3s
# 111:	learn: 2524.5300803	total: 1.04s	remaining: 45.3s
# 112:	learn: 2520.3464223	total: 1.04s	remaining: 45.2s
# 113:	learn: 2513.9830395	total: 1.05s	remaining: 45.3s
# 114:	learn: 2508.4986579	total: 1.06s	remaining: 45.2s
# 115:	learn: 2501.2082053	total: 1.07s	remaining: 45.2s
# 116:	learn: 2494.6103833	total: 1.08s	remaining: 45.1s
# 117:	learn: 2492.2334741	total: 1.09s	remaining: 45.1s
# 118:	learn: 2485.6891936	total: 1.1s	remaining: 45.1s
# 119:	learn: 2479.3323529	total: 1.11s	remaining: 45.1s
# 120:	learn: 2475.3545407	total: 1.12s	remaining: 45.1s
# 121:	learn: 2469.5648659	total: 1.13s	remaining: 45.1s
# 122:	learn: 2466.9679219	total: 1.14s	remaining: 45s
# 123:	learn: 2461.0543130	total: 1.14s	remaining: 45s
# 124:	learn: 2456.5724606	total: 1.15s	remaining: 44.9s
# 125:	learn: 2452.0761306	total: 1.16s	remaining: 44.9s
# 126:	learn: 2447.1248426	total: 1.17s	remaining: 44.9s
# 127:	learn: 2441.4693575	total: 1.18s	remaining: 44.8s
# 128:	learn: 2435.6486766	total: 1.19s	remaining: 44.8s
# 129:	learn: 2429.9871138	total: 1.19s	remaining: 44.8s
# 130:	learn: 2425.7984009	total: 1.2s	remaining: 44.7s
# 131:	learn: 2420.0234388	total: 1.21s	remaining: 44.7s
# 132:	learn: 2415.2862273	total: 1.22s	remaining: 44.8s
# 133:	learn: 2411.2583201	total: 1.23s	remaining: 44.7s
# 134:	learn: 2406.0354926	total: 1.24s	remaining: 44.7s
# 135:	learn: 2403.1729693	total: 1.25s	remaining: 44.6s
# 136:	learn: 2399.4749488	total: 1.26s	remaining: 44.6s
# 137:	learn: 2394.5321761	total: 1.26s	remaining: 44.6s
# 138:	learn: 2389.4633659	total: 1.27s	remaining: 44.5s
# 139:	learn: 2385.9385027	total: 1.28s	remaining: 44.5s
# 140:	learn: 2380.6494591	total: 1.29s	remaining: 44.4s
# 141:	learn: 2378.6860013	total: 1.3s	remaining: 44.4s
# 142:	learn: 2374.9694223	total: 1.31s	remaining: 44.4s
# 143:	learn: 2367.3547820	total: 1.31s	remaining: 44.3s
# 144:	learn: 2363.7545408	total: 1.32s	remaining: 44.3s
# 145:	learn: 2356.6697304	total: 1.33s	remaining: 44.3s
# 146:	learn: 2354.5141300	total: 1.34s	remaining: 44.3s
# 147:	learn: 2350.8894249	total: 1.35s	remaining: 44.3s
# 148:	learn: 2347.2877458	total: 1.36s	remaining: 44.3s
# 149:	learn: 2340.2853245	total: 1.37s	remaining: 44.2s
# 150:	learn: 2336.3655943	total: 1.38s	remaining: 44.2s
# 151:	learn: 2331.1666675	total: 1.38s	remaining: 44.2s
# 152:	learn: 2325.6991612	total: 1.39s	remaining: 44.1s
# 153:	learn: 2322.3458517	total: 1.4s	remaining: 44.1s
# 154:	learn: 2317.9233755	total: 1.41s	remaining: 44.2s
# 155:	learn: 2316.2024915	total: 1.42s	remaining: 44.2s
# 156:	learn: 2312.5422240	total: 1.43s	remaining: 44.2s
# 157:	learn: 2308.0479822	total: 1.44s	remaining: 44.2s
# 158:	learn: 2302.1107270	total: 1.45s	remaining: 44.2s
# 159:	learn: 2296.8508303	total: 1.46s	remaining: 44.1s
# 160:	learn: 2293.5014605	total: 1.47s	remaining: 44.1s
# 161:	learn: 2287.4554381	total: 1.48s	remaining: 44.1s
# 162:	learn: 2284.1904987	total: 1.49s	remaining: 44.1s
# 163:	learn: 2279.8139784	total: 1.49s	remaining: 44.1s
# 164:	learn: 2276.0371976	total: 1.5s	remaining: 44s
# 165:	learn: 2272.7076218	total: 1.51s	remaining: 44s
# 166:	learn: 2268.9624469	total: 1.52s	remaining: 44s
# 167:	learn: 2265.9932139	total: 1.53s	remaining: 44s
# 168:	learn: 2262.2564476	total: 1.54s	remaining: 44.1s
# 169:	learn: 2256.6986836	total: 1.55s	remaining: 44.1s
# 170:	learn: 2252.7750181	total: 1.56s	remaining: 44s
# 171:	learn: 2249.5512199	total: 1.57s	remaining: 44s
# 172:	learn: 2246.2033209	total: 1.58s	remaining: 44s
# 173:	learn: 2244.8885782	total: 1.58s	remaining: 43.9s
# 174:	learn: 2241.8407558	total: 1.59s	remaining: 43.9s
# 175:	learn: 2239.0906643	total: 1.6s	remaining: 43.9s
# 176:	learn: 2234.8882354	total: 1.61s	remaining: 43.9s
# 177:	learn: 2232.4408085	total: 1.62s	remaining: 43.9s
# 178:	learn: 2228.3597609	total: 1.63s	remaining: 43.9s
# 179:	learn: 2223.0279931	total: 1.64s	remaining: 43.9s
# 180:	learn: 2219.6106289	total: 1.65s	remaining: 43.8s
# 181:	learn: 2216.0412111	total: 1.66s	remaining: 43.8s
# 182:	learn: 2212.1976266	total: 1.66s	remaining: 43.8s
# 183:	learn: 2207.6222473	total: 1.67s	remaining: 43.8s
# 184:	learn: 2203.3469708	total: 1.68s	remaining: 43.8s
# 185:	learn: 2202.2082026	total: 1.69s	remaining: 43.7s
# 186:	learn: 2198.3909702	total: 1.7s	remaining: 43.8s
# 187:	learn: 2195.4135336	total: 1.71s	remaining: 43.8s
# 188:	learn: 2191.5682010	total: 1.72s	remaining: 43.8s
# 189:	learn: 2188.8184427	total: 1.73s	remaining: 43.7s
# 190:	learn: 2186.9468977	total: 1.74s	remaining: 43.7s
# 191:	learn: 2185.2034502	total: 1.74s	remaining: 43.7s
# 192:	learn: 2184.1181057	total: 1.75s	remaining: 43.6s
# 193:	learn: 2181.4353378	total: 1.76s	remaining: 43.6s
# 194:	learn: 2177.2772236	total: 1.77s	remaining: 43.6s
# 195:	learn: 2174.2355169	total: 1.78s	remaining: 43.7s
# 196:	learn: 2168.7964716	total: 1.81s	remaining: 44.1s
# 197:	learn: 2165.7094342	total: 1.82s	remaining: 44.2s
# 198:	learn: 2163.6022065	total: 1.83s	remaining: 44.1s
# 199:	learn: 2160.5653509	total: 1.84s	remaining: 44.1s
# 200:	learn: 2156.9767711	total: 1.85s	remaining: 44.1s
# 201:	learn: 2153.0690781	total: 1.85s	remaining: 44s
# 202:	learn: 2149.0326446	total: 1.86s	remaining: 44s
# 203:	learn: 2145.7121973	total: 1.87s	remaining: 44s
# 204:	learn: 2143.7266517	total: 1.88s	remaining: 44s
# 205:	learn: 2141.0128889	total: 1.89s	remaining: 43.9s
# 206:	learn: 2137.9933132	total: 1.9s	remaining: 43.9s
# 207:	learn: 2135.9433847	total: 1.91s	remaining: 44s
# 208:	learn: 2133.4308005	total: 1.92s	remaining: 44s
# 209:	learn: 2128.9853251	total: 1.93s	remaining: 44s
# 210:	learn: 2126.0370880	total: 1.94s	remaining: 44s
# 211:	learn: 2122.6576781	total: 1.95s	remaining: 43.9s
# 212:	learn: 2119.8981779	total: 1.95s	remaining: 43.9s
# 213:	learn: 2117.2153137	total: 1.96s	remaining: 43.9s
# 214:	learn: 2115.7074309	total: 1.97s	remaining: 43.9s
# 215:	learn: 2112.2724145	total: 1.98s	remaining: 43.8s
# 216:	learn: 2109.7640111	total: 1.99s	remaining: 43.8s
# 217:	learn: 2106.6603183	total: 2s	remaining: 43.8s
# 218:	learn: 2104.5105061	total: 2.01s	remaining: 43.8s
# 219:	learn: 2102.2292156	total: 2.02s	remaining: 43.8s
# 220:	learn: 2098.0205864	total: 2.02s	remaining: 43.8s
# 221:	learn: 2096.7976096	total: 2.03s	remaining: 43.8s
# 222:	learn: 2094.2679148	total: 2.04s	remaining: 43.7s
# 223:	learn: 2091.1059098	total: 2.05s	remaining: 43.7s
# 224:	learn: 2088.4263658	total: 2.06s	remaining: 43.7s
# 225:	learn: 2086.4536529	total: 2.07s	remaining: 43.7s
# 226:	learn: 2084.2327871	total: 2.08s	remaining: 43.6s
# 227:	learn: 2081.1440270	total: 2.08s	remaining: 43.6s
# 228:	learn: 2077.4563519	total: 2.09s	remaining: 43.6s
# 229:	learn: 2076.4542616	total: 2.1s	remaining: 43.6s
# 230:	learn: 2073.2431023	total: 2.11s	remaining: 43.6s
# 231:	learn: 2071.5061957	total: 2.12s	remaining: 43.6s
# 232:	learn: 2068.7279292	total: 2.13s	remaining: 43.6s
# 233:	learn: 2065.6161251	total: 2.14s	remaining: 43.5s
# 234:	learn: 2064.2952547	total: 2.15s	remaining: 43.5s
# 235:	learn: 2062.2251274	total: 2.15s	remaining: 43.5s
# 236:	learn: 2058.1767966	total: 2.16s	remaining: 43.5s
# 237:	learn: 2055.8178881	total: 2.17s	remaining: 43.5s
# 238:	learn: 2054.8581089	total: 2.18s	remaining: 43.5s
# 239:	learn: 2050.7597485	total: 2.19s	remaining: 43.4s
# 240:	learn: 2049.1930738	total: 2.2s	remaining: 43.5s
# 241:	learn: 2046.2548050	total: 2.21s	remaining: 43.5s
# 242:	learn: 2044.0626178	total: 2.22s	remaining: 43.4s
# 243:	learn: 2039.7642068	total: 2.23s	remaining: 43.4s
# 244:	learn: 2038.3664567	total: 2.24s	remaining: 43.4s
# 245:	learn: 2034.3713780	total: 2.25s	remaining: 43.4s
# 246:	learn: 2031.3893861	total: 2.25s	remaining: 43.4s
# 247:	learn: 2027.2808013	total: 2.26s	remaining: 43.3s
# 248:	learn: 2024.2067541	total: 2.27s	remaining: 43.3s
# 249:	learn: 2021.3861348	total: 2.28s	remaining: 43.3s
# 250:	learn: 2020.4614778	total: 2.29s	remaining: 43.3s
# 251:	learn: 2018.0571236	total: 2.3s	remaining: 43.3s
# 252:	learn: 2016.5538034	total: 2.31s	remaining: 43.3s
# 253:	learn: 2013.8939318	total: 2.31s	remaining: 43.3s
# 254:	learn: 2012.4158511	total: 2.32s	remaining: 43.2s
# 255:	learn: 2010.0300349	total: 2.33s	remaining: 43.2s
# 256:	learn: 2007.7062284	total: 2.34s	remaining: 43.2s
# 257:	learn: 2006.6297486	total: 2.35s	remaining: 43.2s
# 258:	learn: 2004.2106711	total: 2.36s	remaining: 43.2s
# 259:	learn: 2001.9779049	total: 2.37s	remaining: 43.2s
# 260:	learn: 2000.0328319	total: 2.38s	remaining: 43.2s
# 261:	learn: 1997.7483285	total: 2.38s	remaining: 43.1s
# 262:	learn: 1996.8964450	total: 2.4s	remaining: 43.2s
# 263:	learn: 1994.3881562	total: 2.4s	remaining: 43.1s
# 264:	learn: 1992.9466077	total: 2.41s	remaining: 43.1s
# 265:	learn: 1990.7636979	total: 2.42s	remaining: 43.1s
# 266:	learn: 1988.2894912	total: 2.43s	remaining: 43.1s
# 267:	learn: 1986.0145530	total: 2.44s	remaining: 43.1s
# 268:	learn: 1984.6436542	total: 2.45s	remaining: 43.1s
# 269:	learn: 1981.0409387	total: 2.46s	remaining: 43.1s
# 270:	learn: 1977.6467970	total: 2.47s	remaining: 43s
# 271:	learn: 1974.8433684	total: 2.48s	remaining: 43s
# 272:	learn: 1972.6336782	total: 2.48s	remaining: 43s
# 273:	learn: 1970.1072588	total: 2.49s	remaining: 43s
# 274:	learn: 1968.0338377	total: 2.5s	remaining: 43s
# 275:	learn: 1966.6750050	total: 2.51s	remaining: 42.9s
# 276:	learn: 1963.7054786	total: 2.52s	remaining: 42.9s
# 277:	learn: 1961.7089832	total: 2.53s	remaining: 42.9s
# 278:	learn: 1957.3845569	total: 2.53s	remaining: 42.9s
# 279:	learn: 1955.1518480	total: 2.54s	remaining: 42.9s
# 280:	learn: 1953.2198161	total: 2.55s	remaining: 42.9s
# 281:	learn: 1951.3510262	total: 2.56s	remaining: 42.9s
# 282:	learn: 1950.3738127	total: 2.57s	remaining: 42.8s
# 283:	learn: 1948.5917270	total: 2.58s	remaining: 42.8s
# 284:	learn: 1945.8819384	total: 2.59s	remaining: 42.9s
# 285:	learn: 1943.5960189	total: 2.6s	remaining: 42.9s
# 286:	learn: 1941.3688580	total: 2.61s	remaining: 42.8s
# 287:	learn: 1938.7990049	total: 2.62s	remaining: 42.8s
# 288:	learn: 1937.6423950	total: 2.63s	remaining: 42.8s
# 289:	learn: 1935.5916655	total: 2.63s	remaining: 42.8s
# 290:	learn: 1933.1533174	total: 2.64s	remaining: 42.8s
# 291:	learn: 1930.8068809	total: 2.65s	remaining: 42.8s
# 292:	learn: 1929.3065717	total: 2.66s	remaining: 42.7s
# 293:	learn: 1927.0756791	total: 2.67s	remaining: 42.7s
# 294:	learn: 1925.3127522	total: 2.68s	remaining: 42.7s
# 295:	learn: 1923.3770283	total: 2.69s	remaining: 42.7s
# 296:	learn: 1919.1138062	total: 2.69s	remaining: 42.7s
# 297:	learn: 1917.2034886	total: 2.7s	remaining: 42.6s
# 298:	learn: 1915.9760703	total: 2.71s	remaining: 42.6s
# 299:	learn: 1913.8515317	total: 2.72s	remaining: 42.6s
# 300:	learn: 1911.6589593	total: 2.73s	remaining: 42.6s
# 301:	learn: 1910.5821028	total: 2.74s	remaining: 42.6s
# 302:	learn: 1908.7993123	total: 2.75s	remaining: 42.6s
# 303:	learn: 1906.5653899	total: 2.76s	remaining: 42.6s
# 304:	learn: 1904.7858768	total: 2.78s	remaining: 42.7s
# 305:	learn: 1904.0551694	total: 2.79s	remaining: 42.9s
# 306:	learn: 1900.0475691	total: 2.8s	remaining: 42.9s
# 307:	learn: 1897.9440188	total: 2.81s	remaining: 42.8s
# 308:	learn: 1895.5668441	total: 2.82s	remaining: 42.8s
# 309:	learn: 1893.9659072	total: 2.83s	remaining: 42.8s
# 310:	learn: 1891.9027858	total: 2.84s	remaining: 42.8s
# 311:	learn: 1890.7524998	total: 2.85s	remaining: 42.8s
# 312:	learn: 1889.0462676	total: 2.86s	remaining: 42.8s
# 313:	learn: 1887.3170110	total: 2.87s	remaining: 42.8s
# 314:	learn: 1885.3800800	total: 2.88s	remaining: 42.8s
# 315:	learn: 1884.5235272	total: 2.88s	remaining: 42.8s
# 316:	learn: 1882.5956189	total: 2.89s	remaining: 42.7s
# 317:	learn: 1878.7289167	total: 2.9s	remaining: 42.7s
# 318:	learn: 1877.1868088	total: 2.91s	remaining: 42.7s
# 319:	learn: 1874.3411089	total: 2.92s	remaining: 42.7s
# 320:	learn: 1872.1694512	total: 2.93s	remaining: 42.7s
# 321:	learn: 1870.7545266	total: 2.94s	remaining: 42.7s
# 322:	learn: 1868.8344408	total: 2.94s	remaining: 42.6s
# 323:	learn: 1866.2924612	total: 2.95s	remaining: 42.6s
# 324:	learn: 1864.5170652	total: 2.96s	remaining: 42.6s
# 325:	learn: 1862.7273498	total: 2.97s	remaining: 42.6s
# 326:	learn: 1861.0344820	total: 2.98s	remaining: 42.6s
# 327:	learn: 1859.3137046	total: 2.99s	remaining: 42.6s
# 328:	learn: 1858.6057321	total: 3s	remaining: 42.6s
# 329:	learn: 1857.2441273	total: 3.01s	remaining: 42.6s
# 330:	learn: 1856.1286987	total: 3.02s	remaining: 42.6s
# 331:	learn: 1853.4628905	total: 3.03s	remaining: 42.6s
# 332:	learn: 1851.5497756	total: 3.04s	remaining: 42.5s
# 333:	learn: 1850.1985047	total: 3.04s	remaining: 42.5s
# 334:	learn: 1848.7162708	total: 3.05s	remaining: 42.5s
# 335:	learn: 1847.1434634	total: 3.06s	remaining: 42.5s
# 336:	learn: 1845.0353491	total: 3.07s	remaining: 42.5s
# 337:	learn: 1843.1193151	total: 3.08s	remaining: 42.5s
# 338:	learn: 1841.2456656	total: 3.09s	remaining: 42.5s
# 339:	learn: 1837.3174796	total: 3.1s	remaining: 42.4s
# 340:	learn: 1835.2584184	total: 3.1s	remaining: 42.4s
# 341:	learn: 1832.9775284	total: 3.11s	remaining: 42.4s
# 342:	learn: 1831.0857461	total: 3.12s	remaining: 42.4s
# 343:	learn: 1829.5697886	total: 3.13s	remaining: 42.4s
# 344:	learn: 1827.6978729	total: 3.14s	remaining: 42.4s
# 345:	learn: 1826.1302097	total: 3.15s	remaining: 42.3s
# 346:	learn: 1824.7392836	total: 3.16s	remaining: 42.3s
# 347:	learn: 1823.5284681	total: 3.16s	remaining: 42.3s
# 348:	learn: 1821.1959978	total: 3.17s	remaining: 42.3s
# 349:	learn: 1819.2605510	total: 3.18s	remaining: 42.3s
# 350:	learn: 1818.6527163	total: 3.19s	remaining: 42.3s
# 351:	learn: 1817.4529843	total: 3.2s	remaining: 42.3s
# 352:	learn: 1816.4228779	total: 3.21s	remaining: 42.3s
# 353:	learn: 1814.8990654	total: 3.22s	remaining: 42.2s
# 354:	learn: 1813.2620436	total: 3.23s	remaining: 42.2s
# 355:	learn: 1811.8635391	total: 3.24s	remaining: 42.2s
# 356:	learn: 1810.1104382	total: 3.25s	remaining: 42.2s
# 357:	learn: 1808.6396510	total: 3.26s	remaining: 42.2s
# 358:	learn: 1807.1780747	total: 3.27s	remaining: 42.2s
# 359:	learn: 1805.6759483	total: 3.28s	remaining: 42.2s
# 360:	learn: 1804.2625841	total: 3.29s	remaining: 42.2s
# 361:	learn: 1801.7935342	total: 3.3s	remaining: 42.2s
# 362:	learn: 1799.9157614	total: 3.31s	remaining: 42.2s
# 363:	learn: 1798.7836116	total: 3.31s	remaining: 42.2s
# 364:	learn: 1797.5034252	total: 3.32s	remaining: 42.2s
# 365:	learn: 1796.0554529	total: 3.33s	remaining: 42.2s
# 366:	learn: 1794.4275631	total: 3.34s	remaining: 42.2s
# 367:	learn: 1791.2225758	total: 3.35s	remaining: 42.2s
# 368:	learn: 1789.4553460	total: 3.36s	remaining: 42.1s
# 369:	learn: 1787.5175410	total: 3.37s	remaining: 42.1s
# 370:	learn: 1785.4134000	total: 3.38s	remaining: 42.2s
# 371:	learn: 1784.0547723	total: 3.39s	remaining: 42.1s
# 372:	learn: 1782.1657188	total: 3.4s	remaining: 42.1s
# 373:	learn: 1780.6843216	total: 3.4s	remaining: 42.1s
# 374:	learn: 1779.0027413	total: 3.41s	remaining: 42.1s
# 375:	learn: 1776.2645883	total: 3.42s	remaining: 42.1s
# 376:	learn: 1774.9562728	total: 3.43s	remaining: 42.1s
# 377:	learn: 1773.7546604	total: 3.44s	remaining: 42s
# 378:	learn: 1772.0403464	total: 3.45s	remaining: 42s
# 379:	learn: 1771.1707538	total: 3.45s	remaining: 42s
# 380:	learn: 1769.6383451	total: 3.46s	remaining: 42s
# 381:	learn: 1767.9048359	total: 3.47s	remaining: 42s
# 382:	learn: 1766.8065362	total: 3.48s	remaining: 42s
# 383:	learn: 1765.0994274	total: 3.49s	remaining: 41.9s
# 384:	learn: 1762.9381848	total: 3.5s	remaining: 41.9s
# 385:	learn: 1761.2342795	total: 3.51s	remaining: 41.9s
# 386:	learn: 1760.0534089	total: 3.51s	remaining: 41.9s
# 387:	learn: 1759.1185239	total: 3.52s	remaining: 41.9s
# 388:	learn: 1757.7401646	total: 3.53s	remaining: 41.9s
# 389:	learn: 1757.0756359	total: 3.54s	remaining: 41.9s
# 390:	learn: 1755.7825546	total: 3.55s	remaining: 41.8s
# 391:	learn: 1754.5554780	total: 3.56s	remaining: 41.8s
# 392:	learn: 1751.7953378	total: 3.57s	remaining: 41.8s
# 393:	learn: 1750.4579200	total: 3.58s	remaining: 41.8s
# 394:	learn: 1748.6971706	total: 3.59s	remaining: 41.8s
# 395:	learn: 1747.0419830	total: 3.6s	remaining: 41.8s
# 396:	learn: 1745.6218026	total: 3.6s	remaining: 41.8s
# 397:	learn: 1744.2553096	total: 3.61s	remaining: 41.8s
# 398:	learn: 1743.6629330	total: 3.62s	remaining: 41.8s
# 399:	learn: 1742.4016030	total: 3.63s	remaining: 41.7s
# 400:	learn: 1740.2883431	total: 3.64s	remaining: 41.7s
# 401:	learn: 1738.5438515	total: 3.65s	remaining: 41.7s
# 402:	learn: 1736.4654429	total: 3.65s	remaining: 41.7s
# 403:	learn: 1734.4606008	total: 3.66s	remaining: 41.7s
# 404:	learn: 1732.8802049	total: 3.67s	remaining: 41.7s
# 405:	learn: 1731.6530373	total: 3.68s	remaining: 41.6s
# 406:	learn: 1730.1201628	total: 3.69s	remaining: 41.6s
# 407:	learn: 1727.9553308	total: 3.7s	remaining: 41.6s
# 408:	learn: 1726.6280541	total: 3.71s	remaining: 41.6s
# 409:	learn: 1724.2435758	total: 3.71s	remaining: 41.6s
# 410:	learn: 1722.7606764	total: 3.72s	remaining: 41.6s
# 411:	learn: 1721.3580713	total: 3.73s	remaining: 41.6s
# 412:	learn: 1720.1750270	total: 3.76s	remaining: 41.7s
# 413:	learn: 1719.3880840	total: 3.78s	remaining: 41.8s
# 414:	learn: 1718.6174825	total: 3.79s	remaining: 41.9s
# 415:	learn: 1717.5085730	total: 3.8s	remaining: 41.8s
# 416:	learn: 1716.1164533	total: 3.81s	remaining: 41.8s
# 417:	learn: 1714.7841972	total: 3.81s	remaining: 41.8s
# 418:	learn: 1714.3014885	total: 3.82s	remaining: 41.8s
# 419:	learn: 1712.8241021	total: 3.83s	remaining: 41.8s
# 420:	learn: 1711.6103168	total: 3.84s	remaining: 41.8s
# 421:	learn: 1709.9220199	total: 3.85s	remaining: 41.7s
# 422:	learn: 1708.6379499	total: 3.86s	remaining: 41.7s
# 423:	learn: 1707.1788061	total: 3.87s	remaining: 41.7s
# 424:	learn: 1706.2368770	total: 3.87s	remaining: 41.7s
# 425:	learn: 1704.4419927	total: 3.88s	remaining: 41.7s
# 426:	learn: 1703.2927170	total: 3.89s	remaining: 41.7s
# 427:	learn: 1701.3875517	total: 3.9s	remaining: 41.7s
# 428:	learn: 1699.2494484	total: 3.92s	remaining: 41.8s
# 429:	learn: 1698.3919472	total: 3.93s	remaining: 41.8s
# 430:	learn: 1697.3208124	total: 3.94s	remaining: 41.8s
# 431:	learn: 1695.9648126	total: 3.95s	remaining: 41.8s
# 432:	learn: 1694.4870865	total: 3.96s	remaining: 41.7s
# 433:	learn: 1693.7816000	total: 3.97s	remaining: 41.7s
# 434:	learn: 1692.5103697	total: 3.97s	remaining: 41.7s
# 435:	learn: 1691.5113189	total: 3.98s	remaining: 41.7s
# 436:	learn: 1689.9695873	total: 3.99s	remaining: 41.7s
# 437:	learn: 1689.0049108	total: 4s	remaining: 41.7s
# 438:	learn: 1687.5595188	total: 4.01s	remaining: 41.6s
# 439:	learn: 1685.9064064	total: 4.02s	remaining: 41.6s
# 440:	learn: 1684.7325046	total: 4.02s	remaining: 41.6s
# 441:	learn: 1683.3935971	total: 4.03s	remaining: 41.6s
# 442:	learn: 1682.2378952	total: 4.04s	remaining: 41.6s
# 443:	learn: 1680.6055786	total: 4.05s	remaining: 41.6s
# 444:	learn: 1679.7943186	total: 4.06s	remaining: 41.6s
# 445:	learn: 1678.0483479	total: 4.07s	remaining: 41.5s
# 446:	learn: 1675.1532699	total: 4.08s	remaining: 41.5s
# 447:	learn: 1674.2047437	total: 4.09s	remaining: 41.5s
# 448:	learn: 1672.9890479	total: 4.09s	remaining: 41.5s
# 449:	learn: 1671.9115930	total: 4.1s	remaining: 41.5s
# 450:	learn: 1671.1117265	total: 4.11s	remaining: 41.5s
# 451:	learn: 1669.4190660	total: 4.12s	remaining: 41.5s
# 452:	learn: 1668.4242286	total: 4.13s	remaining: 41.4s
# 453:	learn: 1667.4001481	total: 4.14s	remaining: 41.4s
# 454:	learn: 1666.1823533	total: 4.15s	remaining: 41.4s
# 455:	learn: 1664.9876077	total: 4.16s	remaining: 41.4s
# 456:	learn: 1663.3216972	total: 4.17s	remaining: 41.4s
# 457:	learn: 1662.3170018	total: 4.18s	remaining: 41.4s
# 458:	learn: 1660.8822746	total: 4.18s	remaining: 41.4s
# 459:	learn: 1660.2525747	total: 4.19s	remaining: 41.4s
# 460:	learn: 1658.9349746	total: 4.2s	remaining: 41.4s
# 461:	learn: 1657.4482369	total: 4.21s	remaining: 41.4s
# 462:	learn: 1656.8109982	total: 4.22s	remaining: 41.4s
# 463:	learn: 1655.8653760	total: 4.23s	remaining: 41.4s
# 464:	learn: 1654.4074340	total: 4.24s	remaining: 41.3s
# 465:	learn: 1653.0210149	total: 4.25s	remaining: 41.3s
# 466:	learn: 1651.6756743	total: 4.26s	remaining: 41.3s
# 467:	learn: 1651.0291127	total: 4.26s	remaining: 41.3s
# 468:	learn: 1649.9777686	total: 4.27s	remaining: 41.3s
# 469:	learn: 1648.6984435	total: 4.28s	remaining: 41.3s
# 470:	learn: 1647.4889905	total: 4.29s	remaining: 41.3s
# 471:	learn: 1646.5168611	total: 4.3s	remaining: 41.2s
# 472:	learn: 1645.4254830	total: 4.31s	remaining: 41.2s
# 473:	learn: 1643.7994216	total: 4.32s	remaining: 41.2s
# 474:	learn: 1642.9182415	total: 4.33s	remaining: 41.2s
# 475:	learn: 1641.8420138	total: 4.33s	remaining: 41.2s
# 476:	learn: 1640.6040416	total: 4.34s	remaining: 41.2s
# 477:	learn: 1640.1439578	total: 4.35s	remaining: 41.2s
# 478:	learn: 1638.4072463	total: 4.36s	remaining: 41.2s
# 479:	learn: 1637.2867441	total: 4.37s	remaining: 41.2s
# 480:	learn: 1635.8898450	total: 4.38s	remaining: 41.1s
# 481:	learn: 1635.1720727	total: 4.39s	remaining: 41.1s
# 482:	learn: 1634.4463138	total: 4.4s	remaining: 41.1s
# 483:	learn: 1633.4261102	total: 4.4s	remaining: 41.1s
# 484:	learn: 1632.2549556	total: 4.41s	remaining: 41.1s
# 485:	learn: 1630.8391669	total: 4.42s	remaining: 41.1s
# 486:	learn: 1629.1437433	total: 4.43s	remaining: 41s
# 487:	learn: 1628.1441652	total: 4.44s	remaining: 41s
# 488:	learn: 1626.5905342	total: 4.45s	remaining: 41s
# 489:	learn: 1625.3061757	total: 4.45s	remaining: 41s
# 490:	learn: 1624.2055966	total: 4.46s	remaining: 41s
# 491:	learn: 1623.5535675	total: 4.47s	remaining: 41s
# 492:	learn: 1622.5671152	total: 4.48s	remaining: 41s
# 493:	learn: 1621.2685833	total: 4.49s	remaining: 41s
# 494:	learn: 1620.2991107	total: 4.5s	remaining: 40.9s
# 495:	learn: 1619.0821879	total: 4.51s	remaining: 40.9s
# 496:	learn: 1618.1819340	total: 4.52s	remaining: 40.9s
# 497:	learn: 1617.1239843	total: 4.53s	remaining: 40.9s
# 498:	learn: 1616.1311629	total: 4.54s	remaining: 40.9s
# 499:	learn: 1615.1851561	total: 4.55s	remaining: 40.9s
# 500:	learn: 1614.2832989	total: 4.55s	remaining: 40.9s
# 501:	learn: 1613.3539681	total: 4.56s	remaining: 40.9s
# 502:	learn: 1612.2780419	total: 4.57s	remaining: 40.9s
# 503:	learn: 1611.4828611	total: 4.58s	remaining: 40.9s
# 504:	learn: 1610.4822982	total: 4.59s	remaining: 40.8s
# 505:	learn: 1609.3401883	total: 4.6s	remaining: 40.8s
# 506:	learn: 1608.8893342	total: 4.61s	remaining: 40.8s
# 507:	learn: 1607.4735016	total: 4.61s	remaining: 40.8s
# 508:	learn: 1606.4752599	total: 4.62s	remaining: 40.8s
# 509:	learn: 1605.2047075	total: 4.63s	remaining: 40.8s
# 510:	learn: 1603.9573210	total: 4.64s	remaining: 40.8s
# 511:	learn: 1603.2605451	total: 4.65s	remaining: 40.7s
# 512:	learn: 1602.1754013	total: 4.66s	remaining: 40.7s
# 513:	learn: 1599.6733040	total: 4.67s	remaining: 40.7s
# 514:	learn: 1596.2631578	total: 4.67s	remaining: 40.7s
# 515:	learn: 1594.1938311	total: 4.68s	remaining: 40.7s
# 516:	learn: 1593.0115091	total: 4.69s	remaining: 40.7s
# 517:	learn: 1591.9504491	total: 4.7s	remaining: 40.7s
# 518:	learn: 1590.9303921	total: 4.71s	remaining: 40.7s
# 519:	learn: 1589.7112134	total: 4.73s	remaining: 40.8s
# 520:	learn: 1588.9326361	total: 4.76s	remaining: 40.9s
# 521:	learn: 1587.4826458	total: 4.76s	remaining: 40.9s
# 522:	learn: 1586.6453662	total: 4.77s	remaining: 40.9s
# 523:	learn: 1585.9298799	total: 4.78s	remaining: 40.9s
# 524:	learn: 1584.6945503	total: 4.79s	remaining: 40.8s
# 525:	learn: 1583.6078669	total: 4.8s	remaining: 40.8s
# 526:	learn: 1582.6010129	total: 4.81s	remaining: 40.8s
# 527:	learn: 1581.5557972	total: 4.82s	remaining: 40.8s
# 528:	learn: 1580.6469591	total: 4.82s	remaining: 40.8s
# 529:	learn: 1579.9491084	total: 4.83s	remaining: 40.8s
# 530:	learn: 1578.9380940	total: 4.84s	remaining: 40.7s
# 531:	learn: 1578.0805035	total: 4.85s	remaining: 40.7s
# 532:	learn: 1577.3585550	total: 4.86s	remaining: 40.7s
# 533:	learn: 1576.5463451	total: 4.87s	remaining: 40.7s
# 534:	learn: 1574.8842253	total: 4.88s	remaining: 40.7s
# 535:	learn: 1573.5704521	total: 4.88s	remaining: 40.7s
# 536:	learn: 1572.7418556	total: 4.89s	remaining: 40.7s
# 537:	learn: 1571.9078389	total: 4.9s	remaining: 40.7s
# 538:	learn: 1571.0040037	total: 4.91s	remaining: 40.6s
# 539:	learn: 1569.9591655	total: 4.92s	remaining: 40.6s
# 540:	learn: 1569.6698617	total: 4.93s	remaining: 40.6s
# 541:	learn: 1569.0341635	total: 4.94s	remaining: 40.6s
# 542:	learn: 1567.0141158	total: 4.95s	remaining: 40.6s
# 543:	learn: 1566.0457026	total: 4.96s	remaining: 40.6s
# 544:	learn: 1565.3248504	total: 4.96s	remaining: 40.6s
# 545:	learn: 1564.3756607	total: 4.97s	remaining: 40.6s
# 546:	learn: 1562.6908942	total: 4.98s	remaining: 40.5s
# 547:	learn: 1562.0617672	total: 4.99s	remaining: 40.5s
# 548:	learn: 1561.2001048	total: 5s	remaining: 40.5s
# 549:	learn: 1560.3157642	total: 5.01s	remaining: 40.5s
# 550:	learn: 1559.3487025	total: 5.01s	remaining: 40.5s
# 551:	learn: 1558.1690675	total: 5.02s	remaining: 40.5s
# 552:	learn: 1556.9662195	total: 5.03s	remaining: 40.5s
# 553:	learn: 1555.8930284	total: 5.04s	remaining: 40.5s
# 554:	learn: 1554.5207258	total: 5.05s	remaining: 40.4s
# 555:	learn: 1553.4367940	total: 5.06s	remaining: 40.4s
# 556:	learn: 1552.7694007	total: 5.07s	remaining: 40.4s
# 557:	learn: 1551.7364190	total: 5.07s	remaining: 40.4s
# 558:	learn: 1550.6331640	total: 5.08s	remaining: 40.4s
# 559:	learn: 1549.0848469	total: 5.09s	remaining: 40.4s
# 560:	learn: 1548.3252781	total: 5.1s	remaining: 40.4s
# 561:	learn: 1547.3288368	total: 5.11s	remaining: 40.4s
# 562:	learn: 1546.6939037	total: 5.12s	remaining: 40.4s
# 563:	learn: 1545.7844415	total: 5.13s	remaining: 40.4s
# 564:	learn: 1545.3409403	total: 5.14s	remaining: 40.3s
# 565:	learn: 1544.7557005	total: 5.15s	remaining: 40.3s
# 566:	learn: 1544.4767609	total: 5.16s	remaining: 40.3s
# 567:	learn: 1543.7291236	total: 5.17s	remaining: 40.3s
# 568:	learn: 1543.0263323	total: 5.18s	remaining: 40.3s
# 569:	learn: 1542.0892549	total: 5.18s	remaining: 40.3s
# 570:	learn: 1541.0949321	total: 5.19s	remaining: 40.3s
# 571:	learn: 1540.3223045	total: 5.2s	remaining: 40.3s
# 572:	learn: 1539.4231702	total: 5.21s	remaining: 40.3s
# 573:	learn: 1538.6680084	total: 5.22s	remaining: 40.2s
# 574:	learn: 1537.6535674	total: 5.23s	remaining: 40.2s
# 575:	learn: 1536.7896871	total: 5.24s	remaining: 40.2s
# 576:	learn: 1536.3794505	total: 5.25s	remaining: 40.2s
# 577:	learn: 1534.5435139	total: 5.25s	remaining: 40.2s
# 578:	learn: 1533.5683654	total: 5.26s	remaining: 40.2s
# 579:	learn: 1532.3302422	total: 5.27s	remaining: 40.2s
# 580:	learn: 1532.0615960	total: 5.28s	remaining: 40.2s
# 581:	learn: 1530.9301211	total: 5.29s	remaining: 40.2s
# 582:	learn: 1528.6387869	total: 5.3s	remaining: 40.1s
# 583:	learn: 1527.8150224	total: 5.31s	remaining: 40.1s
# 584:	learn: 1526.1201606	total: 5.32s	remaining: 40.1s
# 585:	learn: 1524.8404431	total: 5.33s	remaining: 40.1s
# 586:	learn: 1523.9516895	total: 5.34s	remaining: 40.1s
# 587:	learn: 1523.3115330	total: 5.34s	remaining: 40.1s
# 588:	learn: 1523.0563267	total: 5.35s	remaining: 40.1s
# 589:	learn: 1522.5111790	total: 5.36s	remaining: 40.1s
# 590:	learn: 1521.6214645	total: 5.37s	remaining: 40.1s
# 591:	learn: 1520.6431182	total: 5.38s	remaining: 40s
# 592:	learn: 1519.7269040	total: 5.39s	remaining: 40s
# 593:	learn: 1519.1638797	total: 5.4s	remaining: 40s
# 594:	learn: 1517.1804334	total: 5.41s	remaining: 40s
# 595:	learn: 1516.6323456	total: 5.42s	remaining: 40s
# 596:	learn: 1516.3886908	total: 5.42s	remaining: 40s
# 597:	learn: 1515.7461729	total: 5.43s	remaining: 40s
# 598:	learn: 1514.8139471	total: 5.44s	remaining: 40s
# 599:	learn: 1513.8252844	total: 5.45s	remaining: 40s
# 600:	learn: 1513.1351448	total: 5.46s	remaining: 40s
# 601:	learn: 1512.2346160	total: 5.47s	remaining: 40s
# 602:	learn: 1511.3489705	total: 5.48s	remaining: 40s
# 603:	learn: 1510.3100675	total: 5.49s	remaining: 39.9s
# 604:	learn: 1509.3794200	total: 5.5s	remaining: 39.9s
# 605:	learn: 1508.5720532	total: 5.5s	remaining: 39.9s
# 606:	learn: 1508.2056423	total: 5.52s	remaining: 39.9s
# 607:	learn: 1507.5698075	total: 5.53s	remaining: 39.9s
# 608:	learn: 1506.4092029	total: 5.54s	remaining: 39.9s
# 609:	learn: 1505.7871154	total: 5.54s	remaining: 39.9s
# 610:	learn: 1505.5539373	total: 5.55s	remaining: 39.9s
# 611:	learn: 1504.8905973	total: 5.56s	remaining: 39.9s
# 612:	learn: 1504.1582262	total: 5.57s	remaining: 39.9s
# 613:	learn: 1503.2035549	total: 5.58s	remaining: 39.9s
# 614:	learn: 1502.3403374	total: 5.59s	remaining: 39.8s
# 615:	learn: 1501.5763255	total: 5.6s	remaining: 39.8s
# 616:	learn: 1500.8273605	total: 5.61s	remaining: 39.8s
# 617:	learn: 1500.0416959	total: 5.61s	remaining: 39.8s
# 618:	learn: 1499.7015423	total: 5.62s	remaining: 39.8s
# 619:	learn: 1498.2295917	total: 5.63s	remaining: 39.8s
# 620:	learn: 1497.4876582	total: 5.64s	remaining: 39.8s
# 621:	learn: 1496.7540132	total: 5.65s	remaining: 39.8s
# 622:	learn: 1495.8980627	total: 5.66s	remaining: 39.8s
# 623:	learn: 1494.7001564	total: 5.67s	remaining: 39.8s
# 624:	learn: 1493.9387470	total: 5.68s	remaining: 39.8s
# 625:	learn: 1493.1804282	total: 5.69s	remaining: 39.8s
# 626:	learn: 1492.8645130	total: 5.71s	remaining: 39.8s
# 627:	learn: 1492.2622782	total: 5.73s	remaining: 39.9s
# 628:	learn: 1491.4192525	total: 5.74s	remaining: 39.9s
# 629:	learn: 1491.1956819	total: 5.75s	remaining: 39.9s
# 630:	learn: 1490.2660674	total: 5.76s	remaining: 39.9s
# 631:	learn: 1489.4199849	total: 5.76s	remaining: 39.8s
# 632:	learn: 1488.6204625	total: 5.77s	remaining: 39.8s
# 633:	learn: 1487.8844963	total: 5.78s	remaining: 39.8s
# 634:	learn: 1487.6721611	total: 5.79s	remaining: 39.8s
# 635:	learn: 1486.8986564	total: 5.8s	remaining: 39.8s
# 636:	learn: 1486.3036631	total: 5.81s	remaining: 39.8s
# 637:	learn: 1485.7748440	total: 5.82s	remaining: 39.8s
# 638:	learn: 1484.8428180	total: 5.83s	remaining: 39.8s
# 639:	learn: 1482.9545205	total: 5.83s	remaining: 39.8s
# 640:	learn: 1482.1331812	total: 5.84s	remaining: 39.7s
# 641:	learn: 1481.5180718	total: 5.85s	remaining: 39.7s
# 642:	learn: 1480.6494142	total: 5.86s	remaining: 39.7s
# 643:	learn: 1479.9132524	total: 5.87s	remaining: 39.7s
# 644:	learn: 1479.1964237	total: 5.88s	remaining: 39.7s
# 645:	learn: 1478.6298641	total: 5.89s	remaining: 39.7s
# 646:	learn: 1477.8210051	total: 5.9s	remaining: 39.7s
# 647:	learn: 1475.2072996	total: 5.91s	remaining: 39.7s
# 648:	learn: 1474.2986521	total: 5.92s	remaining: 39.7s
# 649:	learn: 1472.5093716	total: 5.93s	remaining: 39.7s
# 650:	learn: 1471.8171635	total: 5.93s	remaining: 39.7s
# 651:	learn: 1471.1376371	total: 5.94s	remaining: 39.6s
# 652:	learn: 1470.9319692	total: 5.95s	remaining: 39.6s
# 653:	learn: 1470.3580603	total: 5.96s	remaining: 39.6s
# 654:	learn: 1469.6474942	total: 5.97s	remaining: 39.6s
# 655:	learn: 1468.7041586	total: 5.98s	remaining: 39.6s
# 656:	learn: 1467.8699004	total: 5.99s	remaining: 39.6s
# 657:	learn: 1467.1563235	total: 6s	remaining: 39.6s
# 658:	learn: 1465.7648636	total: 6s	remaining: 39.6s
# 659:	learn: 1464.4854206	total: 6.01s	remaining: 39.5s
# 660:	learn: 1464.3310852	total: 6.03s	remaining: 39.6s
# 661:	learn: 1463.4726214	total: 6.04s	remaining: 39.6s
# 662:	learn: 1462.7225480	total: 6.04s	remaining: 39.5s
# 663:	learn: 1461.3706498	total: 6.05s	remaining: 39.5s
# 664:	learn: 1460.6671208	total: 6.06s	remaining: 39.5s
# 665:	learn: 1459.9144590	total: 6.07s	remaining: 39.5s
# 666:	learn: 1459.2380812	total: 6.08s	remaining: 39.5s
# 667:	learn: 1457.5418676	total: 6.09s	remaining: 39.5s
# 668:	learn: 1456.8498280	total: 6.1s	remaining: 39.5s
# 669:	learn: 1456.1385128	total: 6.11s	remaining: 39.5s
# 670:	learn: 1455.3204195	total: 6.12s	remaining: 39.5s
# 671:	learn: 1454.0289041	total: 6.13s	remaining: 39.5s
# 672:	learn: 1453.1430029	total: 6.14s	remaining: 39.5s
# 673:	learn: 1452.3159042	total: 6.15s	remaining: 39.5s
# 674:	learn: 1451.6892289	total: 6.16s	remaining: 39.5s
# 675:	learn: 1450.8259869	total: 6.17s	remaining: 39.4s
# 676:	learn: 1450.1720220	total: 6.17s	remaining: 39.4s
# 677:	learn: 1449.6678256	total: 6.18s	remaining: 39.4s
# 678:	learn: 1448.6029320	total: 6.19s	remaining: 39.4s
# 679:	learn: 1447.9332077	total: 6.2s	remaining: 39.4s
# 680:	learn: 1447.4752305	total: 6.21s	remaining: 39.4s
# 681:	learn: 1446.9030829	total: 6.22s	remaining: 39.4s
# 682:	learn: 1445.6255117	total: 6.23s	remaining: 39.4s
# 683:	learn: 1444.9329103	total: 6.24s	remaining: 39.3s
# 684:	learn: 1444.2940058	total: 6.24s	remaining: 39.3s
# 685:	learn: 1442.1622771	total: 6.25s	remaining: 39.3s
# 686:	learn: 1441.6104245	total: 6.26s	remaining: 39.3s
# 687:	learn: 1441.0890321	total: 6.27s	remaining: 39.3s
# 688:	learn: 1440.4819238	total: 6.28s	remaining: 39.3s
# 689:	learn: 1439.7463867	total: 6.29s	remaining: 39.3s
# 690:	learn: 1438.4835908	total: 6.3s	remaining: 39.3s
# 691:	learn: 1438.0318418	total: 6.31s	remaining: 39.3s
# 692:	learn: 1437.3002492	total: 6.32s	remaining: 39.3s
# 693:	learn: 1436.4628743	total: 6.33s	remaining: 39.2s
# 694:	learn: 1435.8776089	total: 6.33s	remaining: 39.2s
# 695:	learn: 1435.0381028	total: 6.34s	remaining: 39.2s
# 696:	learn: 1434.2088217	total: 6.35s	remaining: 39.2s
# 697:	learn: 1433.0815328	total: 6.36s	remaining: 39.2s
# 698:	learn: 1432.6009951	total: 6.37s	remaining: 39.2s
# 699:	learn: 1431.9150110	total: 6.38s	remaining: 39.2s
# 700:	learn: 1431.7227674	total: 6.39s	remaining: 39.2s
# 701:	learn: 1431.2008712	total: 6.4s	remaining: 39.2s
# 702:	learn: 1430.6679485	total: 6.41s	remaining: 39.2s
# 703:	learn: 1429.9450201	total: 6.42s	remaining: 39.1s
# 704:	learn: 1428.8346544	total: 6.42s	remaining: 39.1s
# 705:	learn: 1428.2075532	total: 6.43s	remaining: 39.1s
# 706:	learn: 1427.6501494	total: 6.44s	remaining: 39.1s
# 707:	learn: 1426.1715740	total: 6.45s	remaining: 39.1s
# 708:	learn: 1424.8186608	total: 6.46s	remaining: 39.1s
# 709:	learn: 1423.9123289	total: 6.47s	remaining: 39.1s
# 710:	learn: 1423.1775912	total: 6.48s	remaining: 39.1s
# 711:	learn: 1419.5253661	total: 6.49s	remaining: 39.1s
# 712:	learn: 1419.2499595	total: 6.5s	remaining: 39.1s
# 713:	learn: 1418.1215900	total: 6.51s	remaining: 39.1s
# 714:	learn: 1417.6334465	total: 6.52s	remaining: 39.1s
# 715:	learn: 1416.8152963	total: 6.53s	remaining: 39s
# 716:	learn: 1416.0889295	total: 6.53s	remaining: 39s
# 717:	learn: 1415.2405813	total: 6.54s	remaining: 39s
# 718:	learn: 1414.5264755	total: 6.55s	remaining: 39s
# 719:	learn: 1414.0120602	total: 6.56s	remaining: 39s
# 720:	learn: 1413.4322047	total: 6.57s	remaining: 39s
# 721:	learn: 1412.3142875	total: 6.58s	remaining: 39s
# 722:	learn: 1410.7004748	total: 6.58s	remaining: 39s
# 723:	learn: 1410.0613686	total: 6.59s	remaining: 38.9s
# 724:	learn: 1409.3772205	total: 6.6s	remaining: 38.9s
# 725:	learn: 1408.8798048	total: 6.62s	remaining: 39s
# 726:	learn: 1408.2369866	total: 6.63s	remaining: 38.9s
# 727:	learn: 1407.4149360	total: 6.63s	remaining: 38.9s
# 728:	learn: 1406.8045817	total: 6.65s	remaining: 38.9s
# 729:	learn: 1406.2501299	total: 6.66s	remaining: 38.9s
# 730:	learn: 1405.4796647	total: 6.66s	remaining: 38.9s
# 731:	learn: 1404.8072858	total: 6.69s	remaining: 39s
# 732:	learn: 1404.1556919	total: 6.71s	remaining: 39.1s
# 733:	learn: 1403.6863153	total: 6.72s	remaining: 39s
# 734:	learn: 1403.0867674	total: 6.73s	remaining: 39s
# 735:	learn: 1402.4633848	total: 6.74s	remaining: 39s
# 736:	learn: 1402.2212216	total: 6.74s	remaining: 39s
# 737:	learn: 1401.2364374	total: 6.75s	remaining: 39s
# 738:	learn: 1400.2862776	total: 6.76s	remaining: 39s
# 739:	learn: 1399.3802162	total: 6.77s	remaining: 39s
# 740:	learn: 1398.7610060	total: 6.78s	remaining: 39s
# 741:	learn: 1398.2229969	total: 6.79s	remaining: 38.9s
# 742:	learn: 1397.7277642	total: 6.79s	remaining: 38.9s
# 743:	learn: 1396.8991793	total: 6.8s	remaining: 38.9s
# 744:	learn: 1396.4228969	total: 6.81s	remaining: 38.9s
# 745:	learn: 1395.7817878	total: 6.82s	remaining: 38.9s
# 746:	learn: 1392.4649875	total: 6.83s	remaining: 38.9s
# 747:	learn: 1391.9506856	total: 6.84s	remaining: 38.9s
# 748:	learn: 1391.3999210	total: 6.85s	remaining: 38.9s
# 749:	learn: 1390.4307979	total: 6.85s	remaining: 38.8s
# 750:	learn: 1389.9248832	total: 6.86s	remaining: 38.8s
# 751:	learn: 1389.6945574	total: 6.87s	remaining: 38.8s
# 752:	learn: 1389.1856940	total: 6.88s	remaining: 38.8s
# 753:	learn: 1388.6208716	total: 6.89s	remaining: 38.8s
# 754:	learn: 1388.0306684	total: 6.9s	remaining: 38.8s
# 755:	learn: 1387.1908520	total: 6.91s	remaining: 38.8s
# 756:	learn: 1386.6169955	total: 6.92s	remaining: 38.8s
# 757:	learn: 1385.9360345	total: 6.93s	remaining: 38.8s
# 758:	learn: 1385.4772693	total: 6.94s	remaining: 38.8s
# 759:	learn: 1384.9332054	total: 6.94s	remaining: 38.7s
# 760:	learn: 1384.5149621	total: 6.95s	remaining: 38.7s
# 761:	learn: 1383.6534269	total: 6.96s	remaining: 38.7s
# 762:	learn: 1383.1863706	total: 6.97s	remaining: 38.7s
# 763:	learn: 1382.6101515	total: 6.98s	remaining: 38.7s
# 764:	learn: 1382.0095337	total: 6.99s	remaining: 38.7s
# 765:	learn: 1381.4504506	total: 7s	remaining: 38.7s
# 766:	learn: 1380.8489347	total: 7s	remaining: 38.7s
# 767:	learn: 1380.1528401	total: 7.01s	remaining: 38.7s
# 768:	learn: 1379.8764226	total: 7.02s	remaining: 38.6s
# 769:	learn: 1379.0516160	total: 7.03s	remaining: 38.6s
# 770:	learn: 1378.4520396	total: 7.04s	remaining: 38.6s
# 771:	learn: 1377.7238574	total: 7.05s	remaining: 38.6s
# 772:	learn: 1377.0808243	total: 7.06s	remaining: 38.6s
# 773:	learn: 1376.5633978	total: 7.07s	remaining: 38.6s
# 774:	learn: 1375.8189670	total: 7.08s	remaining: 38.6s
# 775:	learn: 1375.3294969	total: 7.09s	remaining: 38.6s
# 776:	learn: 1374.6990975	total: 7.1s	remaining: 38.6s
# 777:	learn: 1374.1239165	total: 7.11s	remaining: 38.6s
# 778:	learn: 1373.4684120	total: 7.11s	remaining: 38.5s
# 779:	learn: 1372.6924623	total: 7.12s	remaining: 38.5s
# 780:	learn: 1372.2027233	total: 7.14s	remaining: 38.6s
# 781:	learn: 1371.8148479	total: 7.16s	remaining: 38.6s
# 782:	learn: 1371.4385064	total: 7.18s	remaining: 38.7s
# 783:	learn: 1370.5365934	total: 7.2s	remaining: 38.7s
# 784:	learn: 1369.8772642	total: 7.21s	remaining: 38.7s
# 785:	learn: 1369.3297800	total: 7.23s	remaining: 38.7s
# 786:	learn: 1368.7019957	total: 7.24s	remaining: 38.8s
# 787:	learn: 1368.3743270	total: 7.26s	remaining: 38.8s
# 788:	learn: 1367.7434329	total: 7.29s	remaining: 38.9s
# 789:	learn: 1366.7673039	total: 7.3s	remaining: 38.9s
# 790:	learn: 1366.0654534	total: 7.31s	remaining: 38.9s
# 791:	learn: 1365.0601517	total: 7.33s	remaining: 38.9s
# 792:	learn: 1364.4399219	total: 7.35s	remaining: 39s
# 793:	learn: 1364.0493636	total: 7.38s	remaining: 39.1s
# 794:	learn: 1363.3934620	total: 7.41s	remaining: 39.2s
# 795:	learn: 1362.7707352	total: 7.42s	remaining: 39.2s
# 796:	learn: 1362.1544234	total: 7.43s	remaining: 39.2s
# 797:	learn: 1361.1289099	total: 7.45s	remaining: 39.2s
# 798:	learn: 1359.6224127	total: 7.46s	remaining: 39.2s
# 799:	learn: 1359.2892021	total: 7.47s	remaining: 39.2s
# 800:	learn: 1358.8232669	total: 7.48s	remaining: 39.2s
# 801:	learn: 1358.1537061	total: 7.5s	remaining: 39.2s
# 802:	learn: 1357.4904243	total: 7.51s	remaining: 39.2s
# 803:	learn: 1356.4511557	total: 7.53s	remaining: 39.3s
# 804:	learn: 1355.3344748	total: 7.54s	remaining: 39.3s
# 805:	learn: 1354.6743327	total: 7.57s	remaining: 39.4s
# 806:	learn: 1354.2129583	total: 7.59s	remaining: 39.4s
# 807:	learn: 1353.7028052	total: 7.61s	remaining: 39.5s
# 808:	learn: 1353.2890034	total: 7.62s	remaining: 39.5s
# 809:	learn: 1352.6964049	total: 7.63s	remaining: 39.5s
# 810:	learn: 1352.0976663	total: 7.66s	remaining: 39.6s
# 811:	learn: 1351.6927072	total: 7.69s	remaining: 39.7s
# 812:	learn: 1351.2574499	total: 7.72s	remaining: 39.8s
# 813:	learn: 1350.6218229	total: 7.75s	remaining: 39.9s
# 814:	learn: 1350.2129676	total: 7.78s	remaining: 39.9s
# 815:	learn: 1349.7545251	total: 7.81s	remaining: 40s
# 816:	learn: 1349.3144964	total: 7.83s	remaining: 40.1s
# 817:	learn: 1348.7670910	total: 7.87s	remaining: 40.2s
# 818:	learn: 1348.2347607	total: 7.9s	remaining: 40.3s
# 819:	learn: 1347.8586037	total: 7.92s	remaining: 40.4s
# 820:	learn: 1347.3763935	total: 7.95s	remaining: 40.5s
# 821:	learn: 1346.9999373	total: 7.97s	remaining: 40.5s
# 822:	learn: 1346.0553832	total: 8s	remaining: 40.6s
# 823:	learn: 1345.6520872	total: 8.03s	remaining: 40.7s
# 824:	learn: 1345.0849905	total: 8.05s	remaining: 40.8s
# 825:	learn: 1344.2756884	total: 8.09s	remaining: 40.9s
# 826:	learn: 1343.5594104	total: 8.11s	remaining: 40.9s
# 827:	learn: 1343.1464557	total: 8.13s	remaining: 41s
# 828:	learn: 1341.6485555	total: 8.14s	remaining: 41s
# 829:	learn: 1341.2809341	total: 8.16s	remaining: 41s
# 830:	learn: 1340.7908802	total: 8.17s	remaining: 41s
# 831:	learn: 1340.2017900	total: 8.18s	remaining: 41s
# 832:	learn: 1339.4700989	total: 8.19s	remaining: 41s
# 833:	learn: 1339.2462935	total: 8.21s	remaining: 41s
# 834:	learn: 1338.6796043	total: 8.22s	remaining: 41s
# 835:	learn: 1338.0634486	total: 8.24s	remaining: 41.1s
# 836:	learn: 1337.2286943	total: 8.26s	remaining: 41.1s
# 837:	learn: 1336.6614144	total: 8.27s	remaining: 41.1s
# 838:	learn: 1335.7350538	total: 8.29s	remaining: 41.1s
# 839:	learn: 1335.3617763	total: 8.29s	remaining: 41.1s
# 840:	learn: 1334.7613795	total: 8.31s	remaining: 41.1s
# 841:	learn: 1334.2511262	total: 8.32s	remaining: 41.1s
# 842:	learn: 1333.6788123	total: 8.34s	remaining: 41.1s
# 843:	learn: 1333.3129180	total: 8.36s	remaining: 41.2s
# 844:	learn: 1332.8615408	total: 8.37s	remaining: 41.1s
# 845:	learn: 1332.5014736	total: 8.38s	remaining: 41.1s
# 846:	learn: 1332.0133578	total: 8.39s	remaining: 41.1s
# 847:	learn: 1331.3038768	total: 8.41s	remaining: 41.2s
# 848:	learn: 1330.6843818	total: 8.44s	remaining: 41.3s
# 849:	learn: 1329.5070428	total: 8.47s	remaining: 41.4s
# 850:	learn: 1328.8994066	total: 8.5s	remaining: 41.4s
# 851:	learn: 1328.4971159	total: 8.53s	remaining: 41.5s
# 852:	learn: 1327.9746587	total: 8.56s	remaining: 41.6s
# 853:	learn: 1327.5574352	total: 8.58s	remaining: 41.7s
# 854:	learn: 1326.8158080	total: 8.61s	remaining: 41.8s
# 855:	learn: 1326.4967791	total: 8.64s	remaining: 41.8s
# 856:	learn: 1325.8702586	total: 8.65s	remaining: 41.8s
# 857:	learn: 1325.0280343	total: 8.67s	remaining: 41.8s
# 858:	learn: 1324.5151500	total: 8.69s	remaining: 41.9s
# 859:	learn: 1323.9673207	total: 8.71s	remaining: 41.9s
# 860:	learn: 1323.4314380	total: 8.73s	remaining: 42s
# 861:	learn: 1323.0486817	total: 8.76s	remaining: 42s
# 862:	learn: 1322.5175908	total: 8.78s	remaining: 42.1s
# 863:	learn: 1321.8418510	total: 8.81s	remaining: 42.2s
# 864:	learn: 1321.3633360	total: 8.82s	remaining: 42.2s
# 865:	learn: 1321.0329287	total: 8.85s	remaining: 42.2s
# 866:	learn: 1320.6156850	total: 8.87s	remaining: 42.3s
# 867:	learn: 1320.0719135	total: 8.88s	remaining: 42.3s
# 868:	learn: 1319.6857119	total: 8.9s	remaining: 42.3s
# 869:	learn: 1319.1951053	total: 8.91s	remaining: 42.3s
# 870:	learn: 1318.8446580	total: 8.92s	remaining: 42.3s
# 871:	learn: 1318.6365890	total: 8.94s	remaining: 42.3s
# 872:	learn: 1318.1240314	total: 8.96s	remaining: 42.4s
# 873:	learn: 1317.3763776	total: 8.99s	remaining: 42.4s
# 874:	learn: 1317.0362696	total: 9s	remaining: 42.4s
# 875:	learn: 1316.5054332	total: 9.01s	remaining: 42.4s
# 876:	learn: 1315.8229311	total: 9.03s	remaining: 42.4s
# 877:	learn: 1315.0635111	total: 9.05s	remaining: 42.5s
# ...
# 4749:	learn: 664.8814685	total: 56.7s	remaining: 2.98s
# 4750:	learn: 664.8505068	total: 56.7s	remaining: 2.97s
# 4751:	learn: 664.7930380	total: 56.7s	remaining: 2.96s
# 4752:	learn: 664.7715412	total: 56.7s	remaining: 2.95s
# 4753:	learn: 664.7159839	total: 56.7s	remaining: 2.94s
# 4754:	learn: 664.6841541	total: 56.7s	remaining: 2.92s
# 4755:	learn: 664.6569763	total: 56.7s	remaining: 2.91s
# 4756:	learn: 664.6249208	total: 56.8s	remaining: 2.9s
# 4757:	learn: 664.5798142	total: 56.8s	remaining: 2.89s
# 4758:	learn: 664.5487459	total: 56.8s	remaining: 2.88s
# 4759:	learn: 664.5141291	total: 56.8s	remaining: 2.86s
# 4760:	learn: 664.4678468	total: 56.8s	remaining: 2.85s
# 4761:	learn: 664.4383500	total: 56.8s	remaining: 2.84s
# 4762:	learn: 664.3451275	total: 56.8s	remaining: 2.83s
# 4763:	learn: 664.3112395	total: 56.8s	remaining: 2.81s
# 4764:	learn: 664.1992580	total: 56.8s	remaining: 2.8s
# 4765:	learn: 664.1670781	total: 56.8s	remaining: 2.79s
# 4766:	learn: 664.1435972	total: 56.8s	remaining: 2.78s
# 4767:	learn: 664.0044461	total: 56.9s	remaining: 2.77s
# 4768:	learn: 663.9733629	total: 56.9s	remaining: 2.75s
# 4769:	learn: 663.9532370	total: 56.9s	remaining: 2.74s
# 4770:	learn: 663.9242197	total: 56.9s	remaining: 2.73s
# 4771:	learn: 663.9091416	total: 56.9s	remaining: 2.72s
# 4772:	learn: 663.8955039	total: 56.9s	remaining: 2.71s
# 4773:	learn: 663.8389894	total: 56.9s	remaining: 2.69s
# 4774:	learn: 663.8055214	total: 56.9s	remaining: 2.68s
# 4775:	learn: 663.6897868	total: 56.9s	remaining: 2.67s
# 4776:	learn: 663.6432684	total: 56.9s	remaining: 2.66s
# 4777:	learn: 663.5486041	total: 56.9s	remaining: 2.65s
# 4778:	learn: 663.5256139	total: 57s	remaining: 2.63s
# 4779:	learn: 663.4843154	total: 57s	remaining: 2.62s
# 4780:	learn: 663.4319808	total: 57s	remaining: 2.61s
# 4781:	learn: 663.4006272	total: 57s	remaining: 2.6s
# 4782:	learn: 663.3638370	total: 57s	remaining: 2.58s
# 4783:	learn: 663.3303524	total: 57s	remaining: 2.57s
# 4784:	learn: 663.2607068	total: 57s	remaining: 2.56s
# 4785:	learn: 663.2292842	total: 57s	remaining: 2.55s
# 4786:	learn: 663.1585455	total: 57s	remaining: 2.54s
# 4787:	learn: 663.1042783	total: 57s	remaining: 2.52s
# 4788:	learn: 663.0725128	total: 57s	remaining: 2.51s
# 4789:	learn: 663.0450001	total: 57s	remaining: 2.5s
# 4790:	learn: 662.9945943	total: 57.1s	remaining: 2.49s
# 4791:	learn: 662.9001334	total: 57.1s	remaining: 2.48s
# 4792:	learn: 662.8486342	total: 57.1s	remaining: 2.46s
# 4793:	learn: 662.8205016	total: 57.1s	remaining: 2.45s
# 4794:	learn: 662.7944090	total: 57.1s	remaining: 2.44s
# 4795:	learn: 662.7674862	total: 57.1s	remaining: 2.43s
# 4796:	learn: 662.7364285	total: 57.1s	remaining: 2.42s
# 4797:	learn: 662.6865179	total: 57.1s	remaining: 2.4s
# 4798:	learn: 662.6400947	total: 57.1s	remaining: 2.39s
# 4799:	learn: 662.6125201	total: 57.1s	remaining: 2.38s
# 4800:	learn: 662.5509783	total: 57.2s	remaining: 2.37s
# 4801:	learn: 662.5166017	total: 57.2s	remaining: 2.36s
# 4802:	learn: 662.4631249	total: 57.2s	remaining: 2.35s
# 4803:	learn: 662.4289289	total: 57.2s	remaining: 2.33s
# 4804:	learn: 662.3979950	total: 57.2s	remaining: 2.32s
# 4805:	learn: 662.3478175	total: 57.2s	remaining: 2.31s
# 4806:	learn: 662.3239051	total: 57.2s	remaining: 2.3s
# 4807:	learn: 662.2821648	total: 57.2s	remaining: 2.28s
# 4808:	learn: 662.1886618	total: 57.2s	remaining: 2.27s
# 4809:	learn: 662.1311724	total: 57.2s	remaining: 2.26s
# 4810:	learn: 662.1206412	total: 57.2s	remaining: 2.25s
# 4811:	learn: 662.1021722	total: 57.3s	remaining: 2.24s
# 4812:	learn: 662.0442674	total: 57.3s	remaining: 2.22s
# 4813:	learn: 662.0175728	total: 57.3s	remaining: 2.21s
# 4814:	learn: 661.9851350	total: 57.3s	remaining: 2.2s
# 4815:	learn: 661.9564193	total: 57.3s	remaining: 2.19s
# 4816:	learn: 661.9192087	total: 57.3s	remaining: 2.18s
# 4817:	learn: 661.8826689	total: 57.3s	remaining: 2.16s
# 4818:	learn: 661.8606502	total: 57.3s	remaining: 2.15s
# 4819:	learn: 661.8338547	total: 57.3s	remaining: 2.14s
# 4820:	learn: 661.8033912	total: 57.3s	remaining: 2.13s
# 4821:	learn: 661.7746145	total: 57.3s	remaining: 2.12s
# 4822:	learn: 661.7389343	total: 57.4s	remaining: 2.1s
# 4823:	learn: 661.7109351	total: 57.4s	remaining: 2.09s
# 4824:	learn: 661.6598010	total: 57.4s	remaining: 2.08s
# 4825:	learn: 661.5295603	total: 57.4s	remaining: 2.07s
# 4826:	learn: 661.4992092	total: 57.4s	remaining: 2.06s
# 4827:	learn: 661.4709189	total: 57.4s	remaining: 2.04s
# 4828:	learn: 661.4320394	total: 57.4s	remaining: 2.03s
# 4829:	learn: 661.3964715	total: 57.4s	remaining: 2.02s
# 4830:	learn: 661.3585532	total: 57.4s	remaining: 2.01s
# 4831:	learn: 661.3212898	total: 57.4s	remaining: 2s
# 4832:	learn: 661.2601132	total: 57.4s	remaining: 1.98s
# 4833:	learn: 661.2214270	total: 57.5s	remaining: 1.97s
# 4834:	learn: 661.2006448	total: 57.5s	remaining: 1.96s
# 4835:	learn: 661.1307076	total: 57.5s	remaining: 1.95s
# 4836:	learn: 661.1104172	total: 57.5s	remaining: 1.94s
# 4837:	learn: 661.0451309	total: 57.5s	remaining: 1.93s
# 4838:	learn: 660.9919997	total: 57.5s	remaining: 1.91s
# 4839:	learn: 660.9662651	total: 57.5s	remaining: 1.9s
# 4840:	learn: 660.9127770	total: 57.5s	remaining: 1.89s
# 4841:	learn: 660.8780927	total: 57.5s	remaining: 1.88s
# 4842:	learn: 660.8423707	total: 57.6s	remaining: 1.86s
# 4843:	learn: 660.8143171	total: 57.6s	remaining: 1.85s
# 4844:	learn: 660.7815050	total: 57.6s	remaining: 1.84s
# 4845:	learn: 660.7364191	total: 57.6s	remaining: 1.83s
# 4846:	learn: 660.7026401	total: 57.6s	remaining: 1.82s
# 4847:	learn: 660.6755963	total: 57.6s	remaining: 1.81s
# 4848:	learn: 660.6369350	total: 57.6s	remaining: 1.79s
# 4849:	learn: 660.6001987	total: 57.6s	remaining: 1.78s
# 4850:	learn: 660.5161312	total: 57.6s	remaining: 1.77s
# 4851:	learn: 660.4714614	total: 57.6s	remaining: 1.76s
# 4852:	learn: 660.4097806	total: 57.7s	remaining: 1.75s
# 4853:	learn: 660.3928912	total: 57.7s	remaining: 1.73s
# 4854:	learn: 660.3333509	total: 57.7s	remaining: 1.72s
# 4855:	learn: 660.3046497	total: 57.7s	remaining: 1.71s
# 4856:	learn: 660.2687717	total: 57.7s	remaining: 1.7s
# 4857:	learn: 660.1985928	total: 57.7s	remaining: 1.69s
# 4858:	learn: 660.1672401	total: 57.7s	remaining: 1.67s
# 4859:	learn: 660.0617504	total: 57.7s	remaining: 1.66s
# 4860:	learn: 660.0068056	total: 57.7s	remaining: 1.65s
# 4861:	learn: 659.9882214	total: 57.7s	remaining: 1.64s
# 4862:	learn: 659.9284798	total: 57.7s	remaining: 1.63s
# 4863:	learn: 659.8892235	total: 57.8s	remaining: 1.61s
# 4864:	learn: 659.8169970	total: 57.8s	remaining: 1.6s
# 4865:	learn: 659.7812416	total: 57.8s	remaining: 1.59s
# 4866:	learn: 659.7380288	total: 57.8s	remaining: 1.58s
# 4867:	learn: 659.6837275	total: 57.8s	remaining: 1.57s
# 4868:	learn: 659.6442997	total: 57.8s	remaining: 1.55s
# 4869:	learn: 659.5446286	total: 57.8s	remaining: 1.54s
# 4870:	learn: 659.5264527	total: 57.8s	remaining: 1.53s
# 4871:	learn: 659.5011122	total: 57.8s	remaining: 1.52s
# 4872:	learn: 659.4697789	total: 57.8s	remaining: 1.51s
# 4873:	learn: 659.4356137	total: 57.8s	remaining: 1.5s
# 4874:	learn: 659.4105024	total: 57.9s	remaining: 1.48s
# 4875:	learn: 659.3828227	total: 57.9s	remaining: 1.47s
# 4876:	learn: 659.3541444	total: 57.9s	remaining: 1.46s
# 4877:	learn: 659.3257112	total: 57.9s	remaining: 1.45s
# 4878:	learn: 659.2792501	total: 57.9s	remaining: 1.44s
# 4879:	learn: 659.2215342	total: 57.9s	remaining: 1.42s
# 4880:	learn: 659.1976201	total: 57.9s	remaining: 1.41s
# 4881:	learn: 659.1727551	total: 57.9s	remaining: 1.4s
# 4882:	learn: 659.1309836	total: 57.9s	remaining: 1.39s
# 4883:	learn: 659.0790203	total: 57.9s	remaining: 1.38s
# 4884:	learn: 659.0476279	total: 57.9s	remaining: 1.36s
# 4885:	learn: 658.9642383	total: 58s	remaining: 1.35s
# 4886:	learn: 658.9157437	total: 58s	remaining: 1.34s
# 4887:	learn: 658.8833452	total: 58s	remaining: 1.33s
# 4888:	learn: 658.8580811	total: 58s	remaining: 1.32s
# 4889:	learn: 658.8017119	total: 58s	remaining: 1.3s
# 4890:	learn: 658.7598742	total: 58s	remaining: 1.29s
# 4891:	learn: 658.7299772	total: 58s	remaining: 1.28s
# 4892:	learn: 658.6889152	total: 58s	remaining: 1.27s
# 4893:	learn: 658.6401921	total: 58s	remaining: 1.26s
# 4894:	learn: 658.6124044	total: 58s	remaining: 1.24s
# 4895:	learn: 658.5884206	total: 58s	remaining: 1.23s
# 4896:	learn: 658.5230928	total: 58.1s	remaining: 1.22s
# 4897:	learn: 658.4774668	total: 58.1s	remaining: 1.21s
# 4898:	learn: 658.4294566	total: 58.1s	remaining: 1.2s
# 4899:	learn: 658.3746928	total: 58.1s	remaining: 1.19s
# 4900:	learn: 658.2795217	total: 58.1s	remaining: 1.17s
# 4901:	learn: 658.2580299	total: 58.1s	remaining: 1.16s
# 4902:	learn: 658.1090397	total: 58.1s	remaining: 1.15s
# 4903:	learn: 658.0597861	total: 58.1s	remaining: 1.14s
# 4904:	learn: 658.0200586	total: 58.1s	remaining: 1.13s
# 4905:	learn: 657.9530163	total: 58.1s	remaining: 1.11s
# 4906:	learn: 657.9170874	total: 58.1s	remaining: 1.1s
# 4907:	learn: 657.8829463	total: 58.2s	remaining: 1.09s
# 4908:	learn: 657.8330531	total: 58.2s	remaining: 1.08s
# 4909:	learn: 657.7964071	total: 58.2s	remaining: 1.07s
# 4910:	learn: 657.7601319	total: 58.2s	remaining: 1.05s
# 4911:	learn: 657.7450417	total: 58.2s	remaining: 1.04s
# 4912:	learn: 657.7184380	total: 58.2s	remaining: 1.03s
# 4913:	learn: 657.6847521	total: 58.2s	remaining: 1.02s
# 4914:	learn: 657.6522538	total: 58.2s	remaining: 1.01s
# 4915:	learn: 657.6152588	total: 58.2s	remaining: 995ms
# 4916:	learn: 657.5696005	total: 58.2s	remaining: 983ms
# 4917:	learn: 657.5401492	total: 58.2s	remaining: 971ms
# 4918:	learn: 657.4861027	total: 58.3s	remaining: 959ms
# 4919:	learn: 657.4547356	total: 58.3s	remaining: 947ms
# 4920:	learn: 657.4416596	total: 58.3s	remaining: 935ms
# 4921:	learn: 657.4205473	total: 58.3s	remaining: 924ms
# 4922:	learn: 657.3636521	total: 58.3s	remaining: 912ms
# 4923:	learn: 657.3150510	total: 58.3s	remaining: 900ms
# 4924:	learn: 657.2861066	total: 58.3s	remaining: 888ms
# 4925:	learn: 657.2354153	total: 58.3s	remaining: 876ms
# 4926:	learn: 657.1781124	total: 58.3s	remaining: 864ms
# 4927:	learn: 657.1681152	total: 58.3s	remaining: 852ms
# 4928:	learn: 657.1269365	total: 58.3s	remaining: 841ms
# 4929:	learn: 657.0831905	total: 58.4s	remaining: 829ms
# 4930:	learn: 657.0600712	total: 58.4s	remaining: 817ms
# 4931:	learn: 657.0510082	total: 58.4s	remaining: 805ms
# 4932:	learn: 657.0424418	total: 58.4s	remaining: 793ms
# 4933:	learn: 656.9952430	total: 58.4s	remaining: 781ms
# 4934:	learn: 656.9640968	total: 58.4s	remaining: 769ms
# 4935:	learn: 656.9252226	total: 58.4s	remaining: 757ms
# 4936:	learn: 656.9146765	total: 58.4s	remaining: 745ms
# 4937:	learn: 656.8778232	total: 58.4s	remaining: 734ms
# 4938:	learn: 656.8387229	total: 58.4s	remaining: 722ms
# 4939:	learn: 656.8231772	total: 58.4s	remaining: 710ms
# 4940:	learn: 656.7909331	total: 58.5s	remaining: 698ms
# 4941:	learn: 656.7630274	total: 58.5s	remaining: 686ms
# 4942:	learn: 656.7313358	total: 58.5s	remaining: 674ms
# 4943:	learn: 656.6875290	total: 58.5s	remaining: 662ms
# 4944:	learn: 656.6275830	total: 58.5s	remaining: 651ms
# 4945:	learn: 656.5158362	total: 58.5s	remaining: 639ms
# 4946:	learn: 656.4804077	total: 58.5s	remaining: 627ms
# 4947:	learn: 656.4434276	total: 58.5s	remaining: 615ms
# 4948:	learn: 656.4026427	total: 58.6s	remaining: 603ms
# 4949:	learn: 656.3743494	total: 58.6s	remaining: 592ms
# 4950:	learn: 656.3293126	total: 58.6s	remaining: 580ms
# 4951:	learn: 656.3016273	total: 58.6s	remaining: 568ms
# 4952:	learn: 656.2615946	total: 58.6s	remaining: 556ms
# 4953:	learn: 656.1418065	total: 58.6s	remaining: 544ms
# 4954:	learn: 656.1185985	total: 58.6s	remaining: 532ms
# 4955:	learn: 656.0763779	total: 58.6s	remaining: 520ms
# 4956:	learn: 656.0323110	total: 58.6s	remaining: 509ms
# 4957:	learn: 655.9982663	total: 58.6s	remaining: 497ms
# 4958:	learn: 655.9721708	total: 58.6s	remaining: 485ms
# 4959:	learn: 655.9484628	total: 58.7s	remaining: 473ms
# 4960:	learn: 655.8974612	total: 58.7s	remaining: 461ms
# 4961:	learn: 655.8747997	total: 58.7s	remaining: 449ms
# 4962:	learn: 655.8360891	total: 58.7s	remaining: 437ms
# 4963:	learn: 655.7922875	total: 58.7s	remaining: 426ms
# 4964:	learn: 655.6918631	total: 58.7s	remaining: 414ms
# 4965:	learn: 655.6543725	total: 58.7s	remaining: 402ms
# 4966:	learn: 655.6283483	total: 58.7s	remaining: 390ms
# 4967:	learn: 655.5959877	total: 58.7s	remaining: 378ms
# 4968:	learn: 655.5568397	total: 58.7s	remaining: 366ms
# 4969:	learn: 655.4973782	total: 58.7s	remaining: 355ms
# 4970:	learn: 655.3135524	total: 58.8s	remaining: 343ms
# 4971:	learn: 655.2795049	total: 58.8s	remaining: 331ms
# 4972:	learn: 655.2569236	total: 58.8s	remaining: 319ms
# 4973:	learn: 655.2195736	total: 58.8s	remaining: 307ms
# 4974:	learn: 655.1878534	total: 58.8s	remaining: 295ms
# 4975:	learn: 655.1590999	total: 58.8s	remaining: 284ms
# 4976:	learn: 655.1336441	total: 58.8s	remaining: 272ms
# 4977:	learn: 655.1088869	total: 58.8s	remaining: 260ms
# 4978:	learn: 655.0870704	total: 58.8s	remaining: 248ms
# 4979:	learn: 655.0619896	total: 58.8s	remaining: 236ms
# 4980:	learn: 655.0182915	total: 58.8s	remaining: 224ms
# 4981:	learn: 654.9748061	total: 58.9s	remaining: 213ms
# 4982:	learn: 654.9440582	total: 58.9s	remaining: 201ms
# 4983:	learn: 654.9324488	total: 58.9s	remaining: 189ms
# 4984:	learn: 654.8838224	total: 58.9s	remaining: 177ms
# 4985:	learn: 654.8170264	total: 58.9s	remaining: 165ms
# 4986:	learn: 654.7995383	total: 58.9s	remaining: 154ms
# 4987:	learn: 654.7656174	total: 58.9s	remaining: 142ms
# 4988:	learn: 654.7200446	total: 58.9s	remaining: 130ms
# 4989:	learn: 654.7037844	total: 58.9s	remaining: 118ms
# 4990:	learn: 654.6657689	total: 58.9s	remaining: 106ms
# 4991:	learn: 654.6480645	total: 58.9s	remaining: 94.5ms
# 4992:	learn: 654.5865833	total: 59s	remaining: 82.7ms
# 4993:	learn: 654.5620350	total: 59s	remaining: 70.8ms
# 4994:	learn: 654.5021620	total: 59s	remaining: 59ms
# 4995:	learn: 654.4590054	total: 59s	remaining: 47.2ms
# 4996:	learn: 654.4187954	total: 59s	remaining: 35.4ms
# 4997:	learn: 654.3230195	total: 59s	remaining: 23.6ms
# 4998:	learn: 654.2258844	total: 59s	remaining: 11.8ms
# 4999:	learn: 654.1686741	total: 59s	remaining: 0us
# RandomizedSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('num',
#                                                                                Pipeline(steps=[('scaler',
#                                                                                                 StandardScaler())]),
#                                                                                ['Δ_crecimiento_GDP',
#                                                                                 'Δ_inflación',
#                                                                                 'Δ_indice_gini',
#                                                                                 'Δ_desempleo',
#                                                                                 'Δ_expectativa_de_vida']),
#                                                                               ('cat',
#                                                                                Pipeline(steps=[('onehot',
#                                                                                                 OneHotEncoder(handle_unknown='ignore'))]),
#                                                                                ['pais_origen',
#                                                                                 'pais_destino'])])),
#                                              ('classifier',
#                                               <catboost.core.CatBoostRegressor object at 0x79de99e60cd0>)]),
#                    n_jobs=-1,
#                    param_distributions={'classifier__depth': [4, 6],
#                                         'classifier__iterations': [1000, 2000,
#                                                                    5000],
#                                         'classifier__learning_rate': [0.1, 0.05,
#                                                                       0.03]},
#                    scoring='neg_mean_squared_error', verbose=2)

# %%
print("Best params:", random_search.best_params_)
print("Best score (neg MSE):", random_search.best_score_)
# Out:
# Best params: {'classifier__learning_rate': 0.1, 'classifier__iterations': 5000, 'classifier__depth': 6}
# Best score (neg MSE): -14737820.15207523

# %%
best_model = random_search.best_estimator_
y_pred_test = best_model.predict(X_test)

y_trainval_pred = best_model.predict(X_trainval)
cb_mse_train = mean_squared_error(y_trainval, y_trainval_pred)

cb_mse_test = mean_squared_error(y_test, y_pred_test)

print("Final Train MSE:", cb_mse_train)
print("Final Test MSE:", cb_mse_test)
# Out:
# Final Train MSE: 427936.65424072783
# Final Test MSE: 10571504.585490922

# %%
from sklearn.metrics import mean_absolute_error

# Predict on train and test sets
y_pred_train_cb = best_model.predict(X_trainval)
y_pred_test_cb = best_model.predict(X_test)

# Calculate MAE
train_mae_cb = mean_absolute_error(y_trainval, y_pred_train_cb)
test_mae_cb = mean_absolute_error(y_test, y_pred_test_cb)

# Print results
print(f"CatBoost - Mean Absolute Error (Train): \t{train_mae_cb:.2f}")
print(f"CatBoost - Mean Absolute Error (Test): \t{test_mae_cb:.2f}")
# Out:
# CatBoost - Mean Absolute Error (Train): 	208.55
# CatBoost - Mean Absolute Error (Test): 	545.46

# %%
from sklearn.metrics import r2_score

# Predictions on validation set (optional if you split manually)
y_val_pred = random_search.predict(X_val)
r2_val = r2_score(y_val, y_val_pred)
print("Validation R²:", r2_val)
# Out:
# Validation R²: 0.9869345428438876

# %%
y_test_pred = random_search.best_estimator_.predict(X_test)
r2_test = r2_score(y_test, y_test_pred)
print("Test R²:", r2_test)
# Out:
# Test R²: 0.6619702436850488

# %% [markdown]
# # **4. Evaluacion y comparacion de resultados**

# %% [markdown]
# En esta etapa compilamos los resultados de los tres modelos para hacer la comparacion y decidir cual es el mejor
#
# Basandonos en esto, profundizaremos en el analisis de los resultados del mejor modelo

# %%
import pandas as pd

# Manualmente hacemos el input de los resultados y creamos un datafram para verlos de manera tabular
data = {
    "Model": ["Randon Forest Regressor", "CatBoost"],
    "Test MSE": [15377448.7462, 10571504.5855],
    "Train MSE": [1478825.0344, 427936.6542],
    "Test R^2": [0.51, 0.66]
}

df_metrics = pd.DataFrame(data)
print(df_metrics.to_markdown())
# Out:
# |    | Model                   |    Test MSE |        Train MSE |   Test R^2 |
# |---:|:------------------------|------------:|-----------------:|-----------:|
# |  0 | Randon Forest Regressor | 1.53774e+07 |      1.47883e+06 |       0.51 |
# |  1 | CatBoost                | 1.05715e+07 | 427937           |       0.66 |

# %% [markdown]
# En cuanto los resultados de MSE ambos muestran cierto nivel de overfitting aunque parece ser un nivel tolerable, pero llama la atencion la amplia diferencia de R^2 entre los modelos, con el CatBoost siendo mucho mejor explicando la variabilidad. A continuacion haremos una representacion visual de estos ressultado y el gap entre train y test en ambos modelos para tomar la decision final

# %%
import matplotlib.pyplot as plt
import numpy as np

# Replace these values with your actual results if needed
iterations = ["Random Forest", "CatBoost"]

train_mse = [1478825.0344, 427936.6542]   # Example: replace with your real training MSEs
test_mse = [15377448.7462, 10571504.5855]   # Example: replace with your real test MSEs

# Calculate generalization gap (test - train)
gap = np.array(test_mse) - np.array(train_mse)

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
bar_width = 0.25
x = np.arange(len(iterations))

ax.bar(x - bar_width, train_mse, width=bar_width, label='Train MSE', color='salmon')
ax.bar(x, test_mse, width=bar_width, label='Test MSE', color='firebrick')
ax.bar(x + bar_width, gap, width=bar_width, label='Generalization Gap', color='gray')

ax.set_ylabel("Mean Squared Error (MSE)")
ax.set_title("Train vs Test MSE and Generalization Gap by Model")
ax.set_xticks(x)
ax.set_xticklabels(iterations)
ax.legend()
ax.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# En la representacion visual queda claro que el mejor modelo es el CatBoost en todas las metricas. CatBoost obtuvo mucho mejores resultados en terminos de MSE tanto para test como para train, como tambien tiene un gap menor que el visto en el Random Forest.
#
# Si le agregamos a esto, que el R^2 del CatBoost es mas alto y le toma significantemente menos tiempo de entrenar, queda claro que es el mejor modelo para predecir el total general y para seguir modificando de ser necesario

# %% [markdown]
# ## **4.1. Evaluaciones finales de modelo final (CatBoost)**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Predict on test set
y_pred_test = best_model.predict(X_test)

# Compute absolute error for color
errors = np.abs(y_test - y_pred_test)

# Create DataFrame for easy plotting
df_plot = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred_test,
    'Error': errors
})

# Plot
plt.figure(figsize=(10, 6))
scatter = plt.scatter(df_plot['Actual'], df_plot['Predicted'],
                      c=df_plot['Error'], cmap='coolwarm', alpha=0.7, edgecolor='k')

plt.plot([df_plot['Actual'].min(), df_plot['Actual'].max()],
         [df_plot['Actual'].min(), df_plot['Actual'].max()],
         'k--', lw=2, label='Perfect Prediction')

plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs. Actual Values (Colored by Error)')
plt.colorbar(scatter, label='Absolute Error')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# En este grafico se puede apreciar como la mayoria de las predicciones muestran un error relativamente bajo hastael rango de valores netos de migracion de 50,000 o menor, a pesar de haber presencia leve de grandes residuos. Por arriba de ese valor se puede ver como el error absoluto va aumentando.
#
# Pareciera que la hay una cantidad similar de residuos positivos como negativos, basandonos en este grafico (la cantidad de puntos por arriba y debajo de la diagonal parecen ser equitativos)

# %%
import matplotlib.pyplot as plt

# Feature to analyze
feature = 'Δ_crecimiento_GDP'

# Get the feature values from the test set
X_feature_test = X_test[feature]

# Predict using the final model
y_test_pred = best_model.predict(X_test)

plt.figure(figsize=(10, 6))

# Plot real values
plt.scatter(X_feature_test, y_test,
            color='red', label='Datos reales (Test)', alpha=0.6)

# Plot predicted values
plt.scatter(X_feature_test, y_test_pred,
            color='blue', label='Predicciones (Test)', alpha=0.6)

plt.title(f'Datos reales vs. Predicciones según {feature}')
plt.xlabel(feature)
plt.ylabel('Migración total (Target)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Emabos graficos podemos ver que el modelo hizo un buen trabajo ne generalizar en la mayoria de los datos, por lo menos hasta valores hasta aprox 50,000 - 70,000. Sin embargo, mientras mas extemos los valores mas le cuesta hacer predicciones correcrtas, con errores tanto a la baja como al alsa.

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np

# Predict using the best model
y_test_pred = best_model.predict(X_test)

# 1. Calculate residuals
residuals = y_test - y_test_pred

# 2. Standardize residuals
standardized_residuals = (residuals - np.mean(residuals)) / np.std(residuals)

# 3. Plot histogram with standard normal overlay
plt.figure(figsize=(10, 6))
plt.hist(standardized_residuals, bins='rice', density=True, alpha=0.6, color='skyblue', label='Residuos estandarizados')

# Overlay a standard normal distribution curve
x = np.linspace(-4, 4, 100)
plt.plot(x, norm.pdf(x, 0, 1), 'r--', linewidth=2, label='Distribución normal estándar')

# Labels and styling
plt.title('Histograma de Residuos Estandarizados')
plt.xlabel('Residuos estandarizados')
plt.ylabel('Densidad')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Por lo general, la mayoria de los residuos estandarizados se encuentran cercanos a 0 aunque ligeramente hacia la izquierda. Esto puede signifciar que el modelo tiene una leve tendencia a subestimar predicciones para ciertos valores
#
# Pareciera que hay una distribucion normal con alta concetracion alrededor de la media y baja desviacion estandar. Sin emabargo, creemos que hay pocos outlies con valores muy extremos que no se pueden apreciar en este grafico debido al cluster principal de los residuos. Considerando esto, decidios hacer mas estudios sobre estos residuos estandarizados para entender su distirbucion

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

# Q-Q Plot
plt.figure(figsize=(8, 6))
stats.probplot(standardized_residuals, dist="norm", plot=plt)
plt.title("Q-Q Plot de los Residuos Estandarizados")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# El Q-Q Plot nos da mas indicios que hay altos niveles de Kurtosis, o en otra palabras, que las colas de esta distribucion son muy pesadas. Este grafico en combinacion con el anterior, nos llevana a la conclusion de que los residuos estandar siguen una distribucion leptocúrtico la cual essta caracterizado por tener un pico alto y colas muy pesadas
#
# muestra que el modelo en general es bueno prediciendo la mayoria de los valores, pero le cuesta hacer predicciones de valores extremos tanto negativos como positivos.
#
# Estos grandes residuos indican que hay pocos outliers pero de gran peso que afectan la capacida de prediccion del modelo, casuanso que el error sea mas grande

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Sort standardized residuals
sorted_resid = np.sort(standardized_residuals)

# Compute empirical CDF values
empirical_cdf = np.arange(1, len(sorted_resid) + 1) / len(sorted_resid)

# Compute theoretical CDF from standard normal
theoretical_cdf = norm.cdf(sorted_resid)

# Plot P-P plot
plt.figure(figsize=(8, 6))
plt.plot(theoretical_cdf, empirical_cdf, marker='o', linestyle='', color='firebrick', label='Datos empíricos')
plt.plot([0, 1], [0, 1], 'k--', label='Distribución Normal Perfecta')

plt.title("P-P Plot de Residuos Estandarizados")
plt.xlabel("CDF Teórica (Normal estándar)")
plt.ylabel("CDF Empírica (Residuos)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# La linea de datos empirico tiene una forma de S, otra indicacion de que no hay normalidad en los residuos
#
# La conclusion final sobre los residuos es que no siguen una distribucion normal. la mayoria se encuentran cercanos a 0, lo que indica que el modelo es bueno prediciendo en la mayor parte, pero la existencia de pocos pero grandes resiudos indica que el modelo le cuesta predecir correctamente valores mas extremos y por ende no esta captando todos los patrones necesarios

# %% [markdown]
# ## **5. Conclusiones finales y recomendaciones**

# %% [markdown]
# ## **5.1 Conclusiones**

# %% [markdown]
# Los dos grandndes logros han sido los siguientes:
#
#
#
# 1.   *Base de datos migratoria:* se logro crear una base de datos de flujos migratorios e indicadores economicos por pais con mas de 77,000 registros. EL objetivo que tenemos en mente es que cualquier investigador, estudiante o persona intereseada pueda utilizar estos datos para analisis independientes a este informe
#
# 2.   *Modelo base de prediccion de flujos migratorios:* Se logro crear un modelo de regresion de Machine Learning (ML) con R^2 de 0.66 para la prediccion de flujos migratorios con base en diferentes indicadores economicos. El modelo es bueno generalizando en su mayor parte, pero falla mas a la hora de predecir valores extremos. Esto en parte creemos que ocurre porque los outliers son pocos pero muy extremos. Adicionalmente, varios de estos outliers esatban en set de test, por lo cual el modelo los estaba viendo por primera vez y sin entrenamiento previo. Con el resultado actual creemos que el modelo ayuda a entender factores que generan presiones migratorias, pero para poder utilizar esta herramienta para implementar presupuesto o regulacion, es necesario mejerorar la capacidad de prediccion
#
# El estudio de flujos migratorio es muy complejo por naturaleza y probablemnet impredecible en gran parte. Valores corresponden a comportamiento humano, el cual en parte esta dirigido por factores logicos, pero que finalmente tienen un componente estocastico. Considerando eso, creemos que los resultados han sido satisfactorios y con psoibilidad de mejora, lo que puede llevar a esta herramienta a ayudar a gobiernos en la toma de decisiones y en la mejora de la calidad de vida de la poblacion nacional y extranjera

# %% [markdown]
# ## **5.2 Recomendaciones**

# %% [markdown]
# Por limitante de tiempo y datos, hay ciertos ajustes que no se pudieron implementar, pero que creemos que valen la pena explorar par mejorar el modelo de prediccion o el valor de la data encontrada

# %% [markdown]
# **Modelo de predicciones**
#
#
#
# *   Quantile regression
# *   Normalizacion vs Standarizacion
# * Redes neuronales
# * mas indicadores (inseguridad, coordenadas de paises, tratados entre paises, indice de criminalidad, indice de corrupcion, etc...)
# * mayor tratamiento de outliers en features (inlflacion en particular)
# * Tuning de hiperparametros mas robusta (opcionde intentar con un Grid Search y mas opciones de hiperparametros)
# *

# %% [markdown]
# **Recomendaciones Generales**
#
#
# *   Crear un interfaz para interactuar con el mddelo y ver resultados filtrados
# *   Creacion de un dashboard de la data original para generacion de insights sobre paises
# * Expandir sobre la base de este modelo de machine learning
# * tomar estas predicciones y resultados como un input para analisis, pero no depender netamente de el
# * Hacer mas evaluaciones de desempeno

# %% [markdown]
# # **6. Consideraciones adicionales**

# %% [markdown]
# ## **6.1. Feature importance de variables numericas**

# %%
# Calculamos el Feature importance despues del Pipeline y compatible con el Random Search
# Idealmente es mejor incluir ne le pipeline

import pandas as pd
import matplotlib.pyplot as plt

# definimos una funcion donde extraemos los nombres de los column trasnformers
def get_feature_names_from_column_transformer(ct):
    feature_names = []

    for name, transformer, columns in ct.transformers_:
        if transformer == 'drop':
            continue
        if transformer == 'passthrough':
            if isinstance(columns, slice):
                # Handle slice objects
                feature_names.extend(ct._feature_names_in[columns])
            else:
                feature_names.extend(columns)
        elif hasattr(transformer, 'get_feature_names_out'):
            # Use scikit-learn >=1.0 interface
            names = transformer.get_feature_names_out(columns)
            feature_names.extend(names)
        else:
            feature_names.extend(columns)

    return feature_names

# Extraemos el mejor piepline del RandomizedSearchCV
best_model = random_search.best_estimator_

# conseguimos los nombres de los features despues del preprocesamiento
preprocessor = best_model.named_steps['preprocessor']
feature_names = get_feature_names_from_column_transformer(preprocessor)

# Mostramos solo los features numericos

# Step 1: Get final feature names after preprocessing
feature_names = get_feature_names_from_column_transformer(
    best_model.named_steps['preprocessor']
)

# Step 2: Get importances from CatBoost model
catboost_model = best_model.named_steps['classifier']
importances = catboost_model.get_feature_importance()

# Step 3: Combine into DataFrame
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
})

# Step 4: Filter only numeric features
numeric_importance_df = importance_df[
    importance_df['Feature'].isin(numeric_features)
].sort_values(by='Importance', ascending=False)

# Step 5: Plot
plt.figure(figsize=(8, 6))
plt.barh(numeric_importance_df['Feature'], numeric_importance_df['Importance'], color='firebrick')
plt.gca().invert_yaxis()
plt.title('Numerical Feature Importances (CatBoost)')
plt.xlabel('Importance')
plt.tight_layout()
plt.show()

# %% [markdown]
# El gráfico presenta las variables numéricas con mayor influencia en el modelo, según la importancia asignada por CatBoost. En esta visualización se excluyen las variables categóricas (como país de origen o destino), ya que al ser codificadas mediante one-hot encoding, generan un alto número de features individuales que dificultan su visualización directa.
#
# Dentro de las variables numéricas, el desempleo y la expectativa de vida emergen como los factores más relevantes para explicar la migración total, seguidos por la inflación y el índice de Gini. En cambio, la variable con menor importancia relativa fue el crecimiento del PIB, lo que sugiere una relación más débil entre este indicador y el fenómeno migratorio observado en el conjunto de datos.
